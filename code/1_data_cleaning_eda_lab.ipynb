# %% [markdown]
# # Predictive Modeling of Hospital Length of Stay and Discharge Type
# # [Step 1: Data cleaning - Laboratory data]
#
# This notebook explores and cleans the **laboratory results dataset** that will be used in the analysis.
#
# The dataset, provided by the Insel Data Science Center (IDSC) of Bern, contains laboratory data spanning approximately 16 years from Inselspital, the university hospital of Bern.
#
# The data includes:
#
# - Laboratory test results from hospital visits.

# %% [markdown]
# ## 1. Import libraries and load datasets

# %%
# Import data manipulation library
import pandas as pd
# Import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set data path
lab_data_path = "/home/anna/Desktop/Master_thesis/raw_data/RITM0154633_del_20240923/RITM0154633_lab.csv"
lab_output_path = "/home/anna/Desktop/Master_thesis/output_data/cleaned_lab_data"

# Load lab dataset 
lab_data = pd.read_csv(lab_data_path)

# %% [markdown]
# ### First look at the dataset:

# %%
display(lab_data)
# Out:
#           dim_patient_bk_pseudo  dim_fall_bk_pseudo              bezeichnung  \
# 0                             1              171465                  Natrium
# 1                             1              171465                   Kalium
# 2                             1              171465              Hämolytisch
# 3                             1              171465                Lipämisch
# 4                             1              171465                Ikterisch
# ...                         ...                 ...                      ...
# 20486999                 240990              415184                      RDW
# 20487000                 240990              415184             Thrombozyten
# 20487001                 240990              415184                      MPV
# 20487002                 240990              415184  Normoblasten maschinell
# 20487003                 240990              415184            Hämatogramm 2
#
#          kurzbezeichnung  methodenummer  ergebnis_numerisch ergebnis_text  \
# 0                    NaN              1               138.0           138
# 1                     KA              3                 4.6           4.6
# 2                   H-Se             42                 4.0             4
# 3                   L-Se             43                 3.0             3
# 4                   I-Se             44                 1.0             1
# ...                  ...            ...                 ...           ...
# 20486999            RDWn           9117                14.3          14.3
# 20487000            THZn           9119               226.0           226
# 20487001            MPVn           9204                 9.0           9.0
# 20487002          NRBCmn           9205                 0.0          0.00
# 20487003          HGR 2n           9702                 NaN           NaN
#
#                 unit
# 0             mmol/L
# 1             mmol/L
# 2            Unknown
# 3            Unknown
# 4            Unknown
# ...              ...
# 20486999           %
# 20487000         G/L
# 20487001          fL
# 20487002  /100 Leuk.
# 20487003     Unknown
#
# [20487004 rows x 8 columns]

# %% [markdown]
# # 2. Lab data cleaning and exploration

# %% [markdown]
# ## 2.1 Extract information about the dataset
#
# The dataset comprises 20,487,004 rows and 8 columns representing different variables.
# These variables include a mix of data types, specifically:
# - one float variable,
# - three integer variables,
# - and four string variables.

# %%
# Information about the dataset
print(lab_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20487004 entries, 0 to 20487003
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   dim_patient_bk_pseudo  int64
#  1   dim_fall_bk_pseudo     int64
#  2   bezeichnung            object
#  3   kurzbezeichnung        object
#  4   methodenummer          int64
#  5   ergebnis_numerisch     float64
#  6   ergebnis_text          object
#  7   unit                   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.2+ GB
# None

# %%
# Optimize memory usage by converting numerical columns to smaller data types
  
lab_data["ergebnis_numerisch"] = lab_data["ergebnis_numerisch"].astype("float32")  # Reduce float precision  

for col in ["dim_patient_bk_pseudo", "dim_fall_bk_pseudo", "methodenummer"]:  
    lab_data[col] = lab_data[col].astype("int32")  # Use smaller integer type

# %%
# Translate columns from German to English

# Translation dictionary
column_translation = {
    "dim_patient_bk_pseudo": "patient_id",
    "dim_fall_bk_pseudo": "case_id",
    "bezeichnung": "test_name",
    "kurzbezeichnung": "test_abbr",
    "methodenummer": "method_number",
    "ergebnis_numerisch": "numeric_result",
    "ergebnis_text": "text_result",
    "unit": "unit"
}

# Rename columns
lab_data.rename(columns=column_translation, inplace=True)

# Check new column names
print(lab_data.columns)

display(lab_data)
# Out:
# Index(['patient_id', 'case_id', 'test_name', 'test_abbr', 'method_number',
#        'numeric_result', 'text_result', 'unit'],
#       dtype='object')
#           patient_id  case_id                test_name test_abbr  \
# 0                  1   171465                  Natrium       NaN
# 1                  1   171465                   Kalium        KA
# 2                  1   171465              Hämolytisch      H-Se
# 3                  1   171465                Lipämisch      L-Se
# 4                  1   171465                Ikterisch      I-Se
# ...              ...      ...                      ...       ...
# 20486999      240990   415184                      RDW      RDWn
# 20487000      240990   415184             Thrombozyten      THZn
# 20487001      240990   415184                      MPV      MPVn
# 20487002      240990   415184  Normoblasten maschinell    NRBCmn
# 20487003      240990   415184            Hämatogramm 2    HGR 2n
#
#           method_number  numeric_result text_result        unit
# 0                     1           138.0         138      mmol/L
# 1                     3             4.6         4.6      mmol/L
# 2                    42             4.0           4     Unknown
# 3                    43             3.0           3     Unknown
# 4                    44             1.0           1     Unknown
# ...                 ...             ...         ...         ...
# 20486999           9117            14.3        14.3           %
# 20487000           9119           226.0         226         G/L
# 20487001           9204             9.0         9.0          fL
# 20487002           9205             0.0        0.00  /100 Leuk.
# 20487003           9702             NaN         NaN     Unknown
#
# [20487004 rows x 8 columns]

# %%
# Get the number of unique entries per column
unique_counts_lab = lab_data.nunique()

# Display results
print(unique_counts_lab)
# Out:
# patient_id        182238
# case_id           311611
# test_name           3469
# test_abbr           4608
# method_number       4695
# numeric_result     62295
# text_result        98458
# unit                 168
# dtype: int64

# %% [markdown]
# ## 2.2 Check for missing values

# %%
# Total missing values
print(f"Total missing values:\n{lab_data.isna().sum().sum()}")

# Check rows with missing values
print(lab_data.isna().sum())
# Out:
# Total missing values:
# 2740336
# patient_id              0
# case_id                 0
# test_name             779
# test_abbr          387136
# method_number           0
# numeric_result    1175245
# text_result       1171815
# unit                 5361
# dtype: int64

# %% [markdown]
# ### 2.2.1 Explore missing values in test_name column

# %%
# Isolate rows with null values
null_test_name = lab_data[lab_data['test_name'].isnull()]

print(f"Number of missing values in test_name column: {len(null_test_name)}")

# Display summary stats of rows with null values
display(null_test_name)
# Out:
# Number of missing values in test_name column: 779
#           patient_id  case_id test_name test_abbr  method_number  \
# 63168            772   352562       NaN    B1adn+          34509
# 63169            772   352562       NaN    K2adn-          34513
# 63170            772   352562       NaN    B2adn-          34514
# 147627          1800   154714       NaN    K1adn+          34502
# 192265          2337    86522       NaN    B1adn-          34508
# ...              ...      ...       ...       ...            ...
# 20443413      240733   402028       NaN    B1-dn+          34510
# 20443414      240733   402028       NaN    B1-dn-          34511
# 20455809      240808   407027       NaN    K1adn-          34501
# 20455810      240808   407027       NaN    B1adn-          34508
# 20455897      240808   421529       NaN    K1-dn-          34504
#
#           numeric_result text_result     unit
# 63168                NaN         NaN  Unknown
# 63169                NaN         NaN  Unknown
# 63170                NaN         NaN  Unknown
# 147627               NaN         NaN  Unknown
# 192265               NaN         NaN  Unknown
# ...                  ...         ...      ...
# 20443413             NaN         NaN  Unknown
# 20443414             NaN         NaN  Unknown
# 20455809             NaN         NaN  Unknown
# 20455810             NaN         NaN  Unknown
# 20455897             NaN         NaN  Unknown
#
# [779 rows x 8 columns]

# %% [markdown]
# ### 2.2.2 Explore missing values in test_abbr column

# %%
# Isolate rows with null values
null_test_abbr = lab_data[lab_data['test_abbr'].isnull()]

print(f"Number of missing values in test_abbr column: {len(null_test_abbr)}")

# Display rows with null values
display(null_test_abbr)
# Out:
# Number of missing values in test_abbr column: 387136
#           patient_id  case_id test_name test_abbr  method_number  \
# 0                  1   171465   Natrium       NaN              1
# 129                1   333396   Natrium       NaN              1
# 249                2    27091   Natrium       NaN              1
# 250                2    27091   Natrium       NaN              1
# 331                2    36154   Natrium       NaN              1
# ...              ...      ...       ...       ...            ...
# 20486787      240988   393440   Natrium       NaN              1
# 20486855      240988   412516   Natrium       NaN              1
# 20486856      240988   412516   Natrium       NaN              1
# 20486949      240989   393141   Natrium       NaN              1
# 20486979      240990   415184   Natrium       NaN              1
#
#           numeric_result text_result    unit
# 0                  138.0         138  mmol/L
# 129                137.0         137  mmol/L
# 249                136.0         136  mmol/L
# 250                135.0         135  mmol/L
# 331                138.0         138  mmol/L
# ...                  ...         ...     ...
# 20486787           140.0         140  mmol/L
# 20486855           139.0         139  mmol/L
# 20486856           137.0         137  mmol/L
# 20486949           141.0         141  mmol/L
# 20486979           138.0         138  mmol/L
#
# [387136 rows x 8 columns]

# %%
# Print unique test_name values where test_abbr is missing
print(f"Unique test_name values where test_abbr is missing: {null_test_abbr['test_name'].unique()}")

# Replace missing test_abbr values where test_name is 'Natrium'
print(f"\nReplace missing test_abbr values where test_name is 'Natrium'...\n")
lab_data.loc[lab_data['test_name'] == 'Natrium', 'test_abbr'] = 'Na'

# Print number of missing values in test_abbr column after replacement
print(f"Number of missing values in test_abbr column after replacement: {lab_data['test_abbr'].isnull().sum()}")
# Out:
# Unique test_name values where test_abbr is missing: ['Natrium']
#
# Replace missing test_abbr values where test_name is 'Natrium'...
#
# Number of missing values in test_abbr column after replacement: 0

# %%
# Remove temporary variable
del null_test_abbr

# %% [markdown]
# ### 2.2.3 Explore missing values in numeric_result and text_result columns

# %%
# Isolate rows with null values
null_num_res = lab_data[lab_data['numeric_result'].isna()]

# Display summary stats of rows with null values
display(null_num_res)
# Out:
#           patient_id  case_id      test_name test_abbr  method_number  \
# 120                1   171465    Neutrophile    NEUm#n           9225
# 121                1   171465    Lymphozyten    LYMm#n           9227
# 122                1   171465      Monozyten    MONm#n           9229
# 123                1   171465    Eosinophile    EOSm#n           9231
# 124                1   171465      Basophile    BASm#n           9233
# ...              ...      ...            ...       ...            ...
# 20486853      240988   393440  Hämatogramm 2    HGR 2n           9702
# 20486933      240988   412516  Hämatogramm 2    HGR 2n           9702
# 20486948      240988   425806  Hämatogramm 2    HGR 2n           9702
# 20486978      240989   393141  Hämatogramm 2    HGR 2n           9702
# 20487003      240990   415184  Hämatogramm 2    HGR 2n           9702
#
#           numeric_result text_result     unit
# 120                  NaN         NaN      G/L
# 121                  NaN         NaN      G/L
# 122                  NaN         NaN      G/L
# 123                  NaN         NaN      G/L
# 124                  NaN         NaN      G/L
# ...                  ...         ...      ...
# 20486853             NaN         NaN  Unknown
# 20486933             NaN         NaN  Unknown
# 20486948             NaN         NaN  Unknown
# 20486978             NaN         NaN  Unknown
# 20487003             NaN         NaN  Unknown
#
# [1175245 rows x 8 columns]

# %%
# Store the initial number of rows
initial_rows = len(lab_data)

# Remove rows where both text_result and numeric_result are missing
lab_data = lab_data.dropna(subset=['text_result', 'numeric_result'], how='all')

# Compute the number of removed rows
removed_rows = initial_rows - len(lab_data)

# Print the result
print(f"Number of rows removed: {removed_rows}")
# Out:
# Number of rows removed: 1171775

# %%
# Total missing values
print(f"Total missing values after cleaning:\n{lab_data.isna().sum().sum()}")

# Check rows with missing values
print(lab_data.isna().sum())
# Out:
# Total missing values after cleaning:
# 8852
# patient_id           0
# case_id              0
# test_name            0
# test_abbr            0
# method_number        0
# numeric_result    3470
# text_result         40
# unit              5342
# dtype: int64

# %%
# Remove temporary variable
del null_num_res

# %% [markdown]
# ### 2.2.4 Explore missing values in numeric_result column

# %%
# Isolate rows with null values in 'numeric_result' column
num_res_null = lab_data[lab_data['numeric_result'].isna()]

print(f"Number of missing values in numeric_result column: {len(num_res_null)}")

# Display summary stats of rows with null values
display(num_res_null)
# Out:
# Number of missing values in numeric_result column: 3470
#           patient_id  case_id          test_name test_abbr  method_number  \
# 5673              54   244839      Fragestellung    CCFFra          59001
# 63096            772   352562     Megakaryopoese    KMAMK1          28030
# 63097            772   352562     Megakaryopoese    KMAMK3          28032
# 63098            772   352562       Erythropoese    KMAER1          28035
# 63099            772   352562       Erythropoese    KMAER3          28037
# ...              ...      ...                ...       ...            ...
# 20470723      240867   419994  Bekannte Diagnose    StB167          54667
# 20470862      240867   423278      Fragestellung    StB149          54649
# 20470863      240867   423278        Medikamente    StB151          54651
# 20470866      240867   423278  Bekannte Diagnose    StB167          54667
# 20472158      240882   396546      Fragestellung    CCFFra          59001
#
#           numeric_result text_result     unit
# 5673                 NaN          AL  Unknown
# 63096                NaN           1  Unknown
# 63097                NaN           0  Unknown
# 63098                NaN           1  Unknown
# 63099                NaN           2  Unknown
# ...                  ...         ...      ...
# 20470723             NaN     AndSynd  Unknown
# 20470862             NaN        k.A.  Unknown
# 20470863             NaN        k.A.  Unknown
# 20470866             NaN        k.A.  Unknown
# 20472158             NaN          AL  Unknown
#
# [3470 rows x 8 columns]

# %%
# Print unique lab test abbreviations with missing numeric_result
print(f"Unique lab TEST_ABBR with missing numeric_result:\n\n{num_res_null['test_abbr'].unique()}\n")

print(f"\n**********************************************************************\n")
# Print unique lab test names with missing numeric_result
print(f"Unique lab TEST_NAME with missing numeric_result:\n\n{num_res_null['test_name'].unique()}\n")
# Out:
# Unique lab TEST_ABBR with missing numeric_result:
#
# ['CCFFra' 'KMAMK1' 'KMAMK3' 'KMAER1' 'KMAER3' 'KMAML1' 'KMAPL1' 'KMAPL4'
#  'KMALY1' 'akid' 'KMAML3' 'KMAEG1' 'igm-q' 'Symp' 'StB149' 'StB151'
#  'StB167' 'Vdiag' 'StB133' 'StB139' 'StB141' 'StB143' 'igaqko' 'igmqko']
#
#
# **********************************************************************
#
# Unique lab TEST_NAME with missing numeric_result:
#
# ['Fragestellung' 'Megakaryopoese' 'Erythropoese' 'Myelopoese'
#  'Plasmazellen' 'Lymphozyten' 'Antikörperidentifikation' 'Eisen'
#  'IgM Quotient' 'Symptome' 'Medikamente' 'Bekannte Diagnose'
#  'Klinischer Verdacht' 'Erwartetes Urinkreatinin' 'Körpergrösse in m'
#  'BMI' 'IgA Quot. korr' 'IgM Quot. korr']

# %%
# Fill missing numeric_result with converted numeric values from text_result
mask = lab_data["numeric_result"].isna()  # Identify missing numeric_result
lab_data.loc[mask, "numeric_result"] = pd.to_numeric(lab_data.loc[mask, "text_result"], errors="coerce")

# Check missing values in 'numeric_result' column after filling
lab_data[lab_data['numeric_result'].isna()]
# Out:
#           patient_id  case_id                 test_name test_abbr  \
# 5673              54   244839             Fragestellung    CCFFra
# 63180            772   352562             Fragestellung    CCFFra
# 88810           1095    96417  Antikörperidentifikation      akid
# 109837          1329   258399             Fragestellung    CCFFra
# 115344          1409   265648             Fragestellung    CCFFra
# ...              ...      ...                       ...       ...
# 20470723      240867   419994         Bekannte Diagnose    StB167
# 20470862      240867   423278             Fragestellung    StB149
# 20470863      240867   423278               Medikamente    StB151
# 20470866      240867   423278         Bekannte Diagnose    StB167
# 20472158      240882   396546             Fragestellung    CCFFra
#
#           method_number  numeric_result text_result     unit
# 5673              59001             NaN          AL  Unknown
# 63180             59001             NaN          AL  Unknown
# 88810              7023             NaN      Anti-s  Unknown
# 109837            59001             NaN        CD34  Unknown
# 115344            59001             NaN         LST  Unknown
# ...                 ...             ...         ...      ...
# 20470723          54667             NaN     AndSynd  Unknown
# 20470862          54649             NaN        k.A.  Unknown
# 20470863          54651             NaN        k.A.  Unknown
# 20470866          54667             NaN        k.A.  Unknown
# 20472158          59001             NaN          AL  Unknown
#
# [1671 rows x 8 columns]

# %%
# Filter rows where 'numeric_result' is missing and 'text_result' starts with '>' or '<'
lab_data[lab_data['numeric_result'].isna() & lab_data['text_result'].str.startswith(('>', '<'), na=False)]
# Out:
# Empty DataFrame
# Columns: [patient_id, case_id, test_name, test_abbr, method_number, numeric_result, text_result, unit]
# Index: []

# %%
# Remove rows where numeric_result is still missing
lab_data = lab_data.dropna(subset=["numeric_result"])

# %%
# Check rows with missing values again
print(lab_data.isna().sum())
# Out:
# patient_id           0
# case_id              0
# test_name            0
# test_abbr            0
# method_number        0
# numeric_result       0
# text_result         40
# unit              5342
# dtype: int64

# %%
# Remove temporary variable
del num_res_null

# %% [markdown]
# ## 2.3 Check and remove duplicated rows

# %%
duplicate_rows_lab = lab_data[lab_data.duplicated()]
print(f"Number of duplicate rows: {len(duplicate_rows_lab)}")
# Out:
# Number of duplicate rows: 25

# %%
# View duplicated rows
display(duplicate_rows_lab)
# Out:
#           patient_id  case_id                 test_name test_abbr  \
# 165491          2019    30187         Heparin, unfrakt.     HAXaU
# 531739          6628   195679                 Basophile    BASO2n
# 724316          8904   370137                       INR     INRiH
# 785263          9644    78608                 Monozyten    MONO2n
# 1154100        14122   126261                       INR     INRiH
# 1541282        19085   231531                Hämatokrit      Hk.n
# 1541284        19085   231531                Hämatokrit       Hkn
# 1803787        22437   220248                       INR     INRiH
# 3990912        49820   380729                       INR     INRiH
# 4152251        51845   387034                       INR     INRiH
# 4471302        55972   275993                       INR     INRiH
# 7636411        95387   157179                Myelozyten       MY2
# 8146773       101830   159671                       INR     INRiH
# 8901009       111216    44091                       INR     INRiH
# 9890139       123384   370703  Neutrophile Granulozyten    NEUTv#
# 11465382      143212   353396         Segmentkernige N.    SEGM2n
# 12502759      156058   129237                       INR     INRiH
# 12898288      161160   283661            Stabkernige N.    STAB2n
# 12948823      161886   213149                       INR     INRiH
# 13189262      165037    63856                       INR     INRiH
# 14358889      179560    95473         Atyp. Lymphozyten    ALYM2n
# 14656508      183201   228469        Quot. %Mikro/%Hypo    MiHypo
# 16558299      206584     9895   Calcium Alb.-korrigiert       Cak
# 17064441      212792   387238                       INR     INRiH
# 17743998      221148   187319                       INR     INRiH
#
#           method_number  numeric_result text_result       unit
# 165491             6152            0.09       < 0.1  AntiXa/mL
# 531739             9130            0.06        0.06        G/L
# 724316             6608            0.96        <1.0    Unknown
# 785263             9132            0.85        0.85        G/L
# 1154100            6608            0.95        <1.0    Unknown
# 1541282            9110            0.37        0.37        L/L
# 1541284            9111            0.37        0.37        L/L
# 1803787            6608            0.97        <1.0    Unknown
# 3990912            6608            0.98        <1.0    Unknown
# 4152251            6608            0.96        <1.0    Unknown
# 4471302            6608            0.96        <1.0    Unknown
# 7636411             142            0.08        0.08    *10^9/l
# 8146773            6608            0.98        <1.0    Unknown
# 8901009            6608            0.96        <1.0    Unknown
# 9890139            9223            0.05        0.05        G/L
# 11465382           9126            0.86        0.86        G/L
# 12502759           6608            0.99        <1.0    Unknown
# 12898288           9124            0.58        0.58        G/L
# 12948823           6608            0.94        <1.0    Unknown
# 13189262           6608            0.99        <1.0    Unknown
# 14358889           9138            0.09        0.09        G/L
# 14656508           9219            6.00         6.0    Unknown
# 16558299          60110            2.16        2.16     mmol/L
# 17064441           6608            0.96        <1.0    Unknown
# 17743998           6608            0.96        <1.0    Unknown

# %%
# Remove duplicate rows and check
lab_data = lab_data.drop_duplicates()
print(f"Number of remaining duplicate rows: {lab_data.duplicated().sum()}")
# Out:
# Number of remaining duplicate rows: 0

# %%
# Remove temporary variable
del duplicate_rows_lab

# %% [markdown]
# ## 2.4 Check plausibility of numeric_result values

# %% [markdown]
# ### 2.4.1 Check negative values

# %%
# Count rows with negative numeric_result
negative_rows = (lab_data['numeric_result'] < 0)
print(f"Number of rows with negative numeric_result: {negative_rows.sum()}")
# Out:
# Number of rows with negative numeric_result: 276389

# %%
# Display rows with negative values
lab_data[lab_data['numeric_result'] < 0]
# Out:
#           patient_id  case_id          test_name test_abbr  method_number  \
# 610                2   335525  Basen-Excess Std.     BE-St             26
# 611                2   335525  Basen-Excess Std.     BE-St             26
# 1666              21   205034     Basen-Excess-2       BE2             23
# 1667              21   205034       Basen-Excess        BE             24
# 1713              22    71424  Basen-Excess Std.     BE-St             26
# ...              ...      ...                ...       ...            ...
# 20486429      240985   423650  Basen-Excess Std.     BE-St             26
# 20486430      240985   423650  Basen-Excess Std.     BE-St             26
# 20486431      240985   423650  Basen-Excess Std.     BE-St             26
# 20486432      240985   423650  Basen-Excess Std.     BE-St             26
# 20486433      240985   423650  Basen-Excess Std.     BE-St             26
#
#           numeric_result text_result    unit
# 610                 -1.9        -1.9  mmol/L
# 611                 -2.1        -2.1  mmol/L
# 1666                -0.8        -0.8  mmol/L
# 1667                -0.8        -0.8  mmol/L
# 1713                -2.4        -2.4  mmol/L
# ...                  ...         ...     ...
# 20486429            -4.9        -4.9  mmol/L
# 20486430            -1.6        -1.6  mmol/L
# 20486431            -1.3        -1.3  mmol/L
# 20486432            -0.1        -0.1  mmol/L
# 20486433            -5.9        -5.9  mmol/L
#
# [276389 rows x 8 columns]

# %%
# Calculate the number of negative results for each test and method combination
negative_counts = (
    lab_data[lab_data['numeric_result'] < 0]
    .groupby(['test_name', 'method_number', 'unit'])
    .size()
    .reset_index(name='negative_count')
    .sort_values(by='negative_count', ascending=False)  # Sorting in descending order
)

print(negative_counts.to_string(index=False))  # Show all rows
# Out:
#                test_name  method_number    unit  negative_count
#        Basen-Excess Std.             26  mmol/L          110488
#             Basen-Excess             24  mmol/L           76873
#           Basen-Excess-2             23  mmol/L           76869
#        Basen-Excess akt.          70004  mmol/L            7362
#        Basen-Excess akt.          70104  mmol/L            2684
#                 D-Dimere           6504    µg/L             676
#              Hämolytisch             47 Unknown             310
#           HIV -1/2 Ag-Ak          60030 Unknown             242
#                     COHb            551       %             131
#       Faktor VII (koag.)           6312       %             121
#            Methämoglobin             35       %             109
#         Faktor X (koag.)           6313       %              91
#                 Delta-He           9214      pg              72
#      C-reaktives Protein             67    mg/L              55
#             Erythrozyten            380     /µL              35
#                     ALAT            103     U/L              32
#                      CEA           2227    µg/L              25
# 1,25-Dihydroxy-VitD CLIA           2431  pmol/L              25
#   LDL ber. n. Friedewald            630  mmol/L              23
#         Faktor V (koag.)           6311       %              19
#                     ASAT            101     U/L              12
#            Creatinin (P)             53  µmol/L              11
#        Fibrinogen Clauss           6105     g/L               9
#        Basen-Excess akt.          70204  mmol/L               9
#         Pankreas-Amylase            122     U/L               7
#                 Zylinder            383     /µL               6
#           Calcium gesamt              7  mmol/L               6
#            Creatinin (U)            343  µmol/L               6
#           Basen-Excess-1             22  mmol/L               6
#                  Natrium            307  mmol/L               6
#                    Pilze            386     /µL               6
#     Lactat-Dehydrogenase            113     U/L               5
#         Hyaline Zylinder            564     /µL               5
#        Faktor II (koag.)           6310       %               5
#                Kristalle            385     /µL               5
#                Ikterisch             49 Unknown               4
#         Bilirubin direkt             71  µmol/L               4
#                 Ammoniak            211  µmol/L               3
#                Magnesium             13  mmol/L               3
#                    Quick           6800       %               2
#              Quick venös           6000       %               2
#       Renin liegend CLIA           2174    ng/L               2
#      Übergangsepithelien            560     /µL               2
#                  Glucose             51  mmol/L               2
#          HDL-Cholesterin            629  mmol/L               2
#                  Albumin             65     g/L               1
#                  Glucose            257  mmol/L               1
#         Bilirubin gesamt             69  µmol/L               1
#           Creatin-Kinase            117     U/L               1
#                Creatinin           2919  µmol/L               1
#                Bakterien            384     /µL               1
#        Plattenepithelien            559     /µL               1
#         Pankreas-Amylase           1124     U/L               1
#         Nierenepithelien            561     /µL               1
#            LDH nach IFCC            114     U/L               1
#                  Albumin           1065     g/L               1
#              Haptoglobin           4011     g/L               1
#                Lipämisch             48 Unknown               1
#               Leukozyten            381     /µL               1
#                Harnsäure             57  µmol/L               1
#                      CEA           2228    µg/L               1
#     Bilirubin gesamt ABL             86  µmol/L               1

# %% [markdown]
# Basen-Excess is the only test in the list that can have physiological negative values. Therefore, it makes sense to keep only Basen-Excess in the analysis and remove rows for all other tests with negative results, as they are likely due to errors rather than meaningful physiological measurements.

# %%
# Keep all tests with "Basen-Excess" in the test name and remove other tests with negative values
lab_data = lab_data[~((lab_data['numeric_result'] < 0) & (~lab_data['test_name'].str.contains('Basen-Excess')))]

# Display rows with negative values
lab_data[lab_data['numeric_result'] < 0]
# Out:
#           patient_id  case_id          test_name test_abbr  method_number  \
# 610                2   335525  Basen-Excess Std.     BE-St             26
# 611                2   335525  Basen-Excess Std.     BE-St             26
# 1666              21   205034     Basen-Excess-2       BE2             23
# 1667              21   205034       Basen-Excess        BE             24
# 1713              22    71424  Basen-Excess Std.     BE-St             26
# ...              ...      ...                ...       ...            ...
# 20486429      240985   423650  Basen-Excess Std.     BE-St             26
# 20486430      240985   423650  Basen-Excess Std.     BE-St             26
# 20486431      240985   423650  Basen-Excess Std.     BE-St             26
# 20486432      240985   423650  Basen-Excess Std.     BE-St             26
# 20486433      240985   423650  Basen-Excess Std.     BE-St             26
#
#           numeric_result text_result    unit
# 610                 -1.9        -1.9  mmol/L
# 611                 -2.1        -2.1  mmol/L
# 1666                -0.8        -0.8  mmol/L
# 1667                -0.8        -0.8  mmol/L
# 1713                -2.4        -2.4  mmol/L
# ...                  ...         ...     ...
# 20486429            -4.9        -4.9  mmol/L
# 20486430            -1.6        -1.6  mmol/L
# 20486431            -1.3        -1.3  mmol/L
# 20486432            -0.1        -0.1  mmol/L
# 20486433            -5.9        -5.9  mmol/L
#
# [274291 rows x 8 columns]

# %%
# Check after cleaning: print the number of negative results for each test and method combination
print(
    lab_data[lab_data['numeric_result'] < 0]
    .groupby(['test_name', 'method_number', 'unit'])
    .size()
    .reset_index(name='negative_count')
    .sort_values(by='negative_count', ascending=False)  # Sorting in descending order
)
# Out:
#            test_name  method_number    unit  negative_count
# 1  Basen-Excess Std.             26  mmol/L          110488
# 0       Basen-Excess             24  mmol/L           76873
# 6     Basen-Excess-2             23  mmol/L           76869
# 2  Basen-Excess akt.          70004  mmol/L            7362
# 3  Basen-Excess akt.          70104  mmol/L            2684
# 4  Basen-Excess akt.          70204  mmol/L               9
# 5     Basen-Excess-1             22  mmol/L               6

# %% [markdown]
# ### 2.4.2 Filtering out values incompatible with life
#
# Limits were defined for specific tests to remove values incompatible with life.
#
# *NOTE: Consider other ranges, or addressing outliers later in the analysis!*
#
# - Natrium: values below 100 mmol/L and above 191 mmol/L (Vogt, W. et al., 1992).
# - Kalium: values below 1.2 mmol/L and above 9.8 mmol/L (Janssens, P. M. W. *et al.,* 2021).
# - Chloride: values below 65 mmol/L and above 138 mmol/L (Vogt, W. et al., 1992).
# - pH: values below 6.8 and above 7.8 (for both venous and arterial) (Janssens, P. M. W. *et al.,* 2021).

# %%
# Define the limits for each test
limits = {
    'KA': {'min': 1.2, 'max': 9.8},  # Kalium (KA)
    'Na': {'min': 100, 'max': 191},  # Natrium (NA)
    'CL': {'min': 65, 'max': 138},   # Chloride (CL)
    'pH': {'min': 6.8, 'max': 7.8}   # pH (PH)
}

# Loop through each test abbreviation in limits and filter out rows outside the range
for test_abbr, limit in limits.items():
    lab_data = lab_data[~((lab_data['test_abbr'] == test_abbr) & 
                          ((lab_data['numeric_result'] < limit['min']) | 
                           (lab_data['numeric_result'] > limit['max'])))]

# After running this, `lab_data` will have rows removed where numeric_result is outside the specified range

lab_data
# Out:
#           patient_id  case_id                test_name test_abbr  \
# 0                  1   171465                  Natrium        Na
# 1                  1   171465                   Kalium        KA
# 2                  1   171465              Hämolytisch      H-Se
# 3                  1   171465                Lipämisch      L-Se
# 4                  1   171465                Ikterisch      I-Se
# ...              ...      ...                      ...       ...
# 20486998      240990   415184                     MCHC     MCHCn
# 20486999      240990   415184                      RDW      RDWn
# 20487000      240990   415184             Thrombozyten      THZn
# 20487001      240990   415184                      MPV      MPVn
# 20487002      240990   415184  Normoblasten maschinell    NRBCmn
#
#           method_number  numeric_result text_result        unit
# 0                     1           138.0         138      mmol/L
# 1                     3             4.6         4.6      mmol/L
# 2                    42             4.0           4     Unknown
# 3                    43             3.0           3     Unknown
# 4                    44             1.0           1     Unknown
# ...                 ...             ...         ...         ...
# 20486998           9116           333.0         333         g/L
# 20486999           9117            14.3        14.3           %
# 20487000           9119           226.0         226         G/L
# 20487001           9204             9.0         9.0          fL
# 20487002           9205             0.0        0.00  /100 Leuk.
#
# [19298257 rows x 8 columns]

# %% [markdown]
# ### 2.4.3 Check for Outliers in the Remaining Laboratory Tests

# %% [markdown]
# **Most important laboratory test**
#
# Select the most frequent laboratory measurements with less than 80% missing cases.

# %%
# Count unique cases per lab test directly, avoiding an intermediate df_unique
lab_test_counts = lab_data.groupby("test_abbr", as_index=False)["case_id"].nunique()
lab_test_counts.rename(columns={"case_id": "num_cases"}, inplace=True)

# Total number of unique cases (computed once)
total_cases = lab_data["case_id"].nunique()

# Compute missing percentage efficiently
lab_test_counts["missing_percentage"] = 100 - (lab_test_counts["num_cases"] / total_cases * 100)

# Optionally sort (skip if not required for performance reasons)
lab_test_counts.sort_values(by="num_cases", ascending=False, inplace=True)

# If you only need test_abbr and missing_percentage
missing_counts = lab_test_counts[["test_abbr", "missing_percentage"]]

# Define the threshold for missing percentage (keep tests with < 80% missing)
filtered_lab_tests = missing_counts[missing_counts["missing_percentage"] < 80]

# %%
print(filtered_lab_tests.to_string(index=False))
# Out:
# test_abbr  missing_percentage
#        KA           14.163553
#     Leukn           15.379800
#       Hbn           15.380763
#      Eryn           15.382368
#       Hkn           15.383331
#      THZn           15.384936
#     MCHCn           15.385257
#      MCHn           15.385578
#      MCVn           15.385578
#      RDWn           15.458123
#      MPVn           16.120655
#        Na           16.224657
#         L           18.770463
#         I           18.771426
#         H           18.830489
#        GL           22.091471
#    NRBCmn           23.693232
#       CRP           24.653968
#        CR           25.418256
#     INRiH           25.541196
#      QUHD           25.546653
#    ENTN1n           29.520884
#    EPIGFR           30.735205
#    Quicks           36.439916
#      ASAT           61.683230
#      ALAT           62.087362
#    Ben-ID           64.571858
#       GGT           65.177574
#      UREA           65.340960
#        CA           71.260737
#     EC3-U           71.549632
#     PH4-U           71.550595
#     GLUC3           71.550595
#     BI3-U           71.550916
#      URO3           71.550916
#     LK3-U           71.551237
#     PROT3           71.551237
#     NITR3           71.551237
#     KETO3           71.551879
#     SPEZ3           71.560867
#    NEUm#n           72.151175
#    LYMm#n           72.279894
#        CK           72.424984
#       BIg           72.885610
#        AP           73.542686
#    MONm#n           73.762888
#    EOSm#n           73.762888
#    BASm#n           73.763209
#    FARBE3           74.653005
#    TRUEB3           74.656215
#      UST1           75.393539
#     IGm#n           75.403490
#       tHb           75.905204
#      LACT           76.385090
#      EART           76.789222
#      Tbga           76.915052
#        pH           76.991128
#      pCO2           77.173131
#       pO2           77.422544
#     BA-Ux           78.135793
#     CO-HB           78.270932
#      MTHB           78.275105
#     LK-Ux           78.371082
#    KRI-Ux           78.640075
#    ERY-Ux           78.720645
#    TNT_hn           79.250607
#    TNThsn           79.310954
#     PI-Ux           79.377399
#      H-Se           79.561971
#      L-Se           79.561971
#      I-Se           79.561971

# %% [markdown]
# In the list of most frequent laboratory tests, the following code checks the test name corresponding to the abbreviation:
#
# - **Ben-ID** is Benutzer (user)  ->  remove (likely not a relevant test)
# - **FARBE3** is Farbe (color)  ->  keep, eventually not to be included in the modeling
# - **TRUEB3** is Trübung (turbidity)  ->  keep, eventually excluded from the modeling
# - **QUHD** is Quick  ->  keep (likely a valid laboratory test)
# - **ENTN1n** is Entnahmeart (sample type)  ->  keep as metadata (useful for understanding sample collection)
#
# In addition:
# - **TNT_hn** is Hilfsanalyse (auxiliary analysis)  ->  remove (not relevant to analysis)

# %%
lab_data[lab_data["test_abbr"].isin(["Ben-ID", "EART", "FARBE3", "TRUEB3", "QUHD", "ENTN1n"])]["test_name"].unique()
# Out:
# array(['Farbe', 'Trübung', 'Benutzer', 'Quick', 'Entnahmeart',
#        'Quick venös'], dtype=object)

# %%
# List of test abbreviations to be removed based on their descriptions
tests_to_remove = [
    "Ben-ID",  # Benutzer (user)
    "TNT_hn"   # Hilfsanalyse (auxiliary analysis)
]

# Filter out the rows where 'test_abbr' is in the tests_to_remove list
lab_data = lab_data[~lab_data["test_abbr"].isin(tests_to_remove)]

# %%
# Filter rows where 'text_result' starts with '>' or '<'
lab_data[lab_data['text_result'].str.startswith(('>', '<'), na=False)]
# Out:
#           patient_id  case_id            test_name test_abbr  method_number  \
# 16                 1   171465    eGFR nach CKD-EPI    EPIGFR             64
# 165                1   333396            Bakterien     BA-Ux            384
# 167                1   333396                Pilze     PI-Ux            386
# 170                1   333396         Erythrozyten    ERY-CH            490
# 171                1   333396           Leukozyten     LK-CH            491
# ...              ...      ...                  ...       ...            ...
# 20486899      240988   412516                  TSH       TSH           2005
# 20486903      240988   412516             Folsäure    FOLIII           2374
# 20486959      240989   393141    eGFR nach CKD-EPI    EPIGFR             64
# 20486960      240989   393141  C-reaktives Protein       CRP             67
# 20486986      240990   415184    eGFR nach CKD-EPI    EPIGFR             64
#
#           numeric_result text_result     unit
# 16            100.000000        > 90   mL/min
# 165         32164.800781     > 10000      /µL
# 167             2.800000         <10      /µL
# 170             5.000000         >20  Unknown
# 171             5.000000         >20  Unknown
# ...                  ...         ...      ...
# 20486899      101.000000       > 100     mU/L
# 20486903       50.000000      > 45.4   nmol/L
# 20486959      100.000000        > 90   mL/min
# 20486960        1.000000         < 3     mg/L
# 20486986      114.000000        > 90   mL/min
#
# [574018 rows x 8 columns]

# %% [markdown]
# In the list of most frequent laboratory tests, check and remove extreme values that are most likely placeholders or errors, as identified in a previous exploratory data analysis step.
#
# **Note**: as alternative, for placeholders, consider replacing them with upper threshold in the corresponding'text_result' column.

# %%
# Define the conditions for extreme values
extreme_values = (
    ((lab_data["test_abbr"] == "INRiH") & (lab_data["numeric_result"].isin([9999, 5001.36]))) |
    ((lab_data["test_abbr"] == "QUHD") & (lab_data["numeric_result"] == 9999)) |
    ((lab_data["test_abbr"] == "Tbga") & (lab_data["numeric_result"] == 34103))
)

# Display rows that will be removed
lab_data[extreme_values]
# Out:
#           patient_id  case_id         test_name test_abbr  method_number  \
# 3833              33   187592             Quick      QUHD           6800
# 1033900        12633    71315             Quick      QUHD           6800
# 3867468        48306    53283  Körpertemperatur      Tbga             32
# 4356463        54491   189920             Quick      QUHD           6800
# 5566541        69617   326336             Quick      QUHD           6800
# 5951445        74276     4105             Quick      QUHD           6800
# 7425897        92754   313524             Quick      QUHD           6800
# 7871705        98342   371573             Quick      QUHD           6800
# 10226695      127669   182835             Quick      QUHD           6800
# 11330332      141456   185165             Quick      QUHD           6800
# 11549930      144261   160510             Quick      QUHD           6800
# 12437372      155172   193693             Quick      QUHD           6800
# 13043903      163267   299360             Quick      QUHD           6800
# 13485166      168772   231567             Quick      QUHD           6800
# 14426205      180452   247446             Quick      QUHD           6800
# 14690551      183621   354722             Quick      QUHD           6800
# 15264124      190697    29416               INR     INRiH           6608
# 15711795      196272    34017             Quick      QUHD           6800
# 16278276      203370   185997             Quick      QUHD           6800
# 16925338      211103   131809             Quick      QUHD           6800
# 18422030      227732   428070             Quick      QUHD           6800
# 18549884      228559   418970             Quick      QUHD           6800
# 18549941      228559   425584             Quick      QUHD           6800
# 18983364      231395   411345             Quick      QUHD           6800
# 19279147      233219   399888               INR     INRiH           6608
# 19804257      236480   399515             Quick      QUHD           6800
#
#           numeric_result text_result     unit
# 3833              9999.0        >100        %
# 1033900           9999.0        >100        %
# 3867468          34103.0     34103.0       °C
# 4356463           9999.0        >100        %
# 5566541           9999.0        >100        %
# 5951445           9999.0        >100        %
# 7425897           9999.0        >100        %
# 7871705           9999.0        >100        %
# 10226695          9999.0        >100        %
# 11330332          9999.0        >100        %
# 11549930          9999.0        >100        %
# 12437372          9999.0        >100        %
# 13043903          9999.0        >100        %
# 13485166          9999.0        >100        %
# 14426205          9999.0        >100        %
# 14690551          9999.0        >100        %
# 15264124          9999.0        >5.5  Unknown
# 15711795          9999.0        >100        %
# 16278276          9999.0        >100        %
# 16925338          9999.0        >100        %
# 18422030          9999.0        >100        %
# 18549884          9999.0        >100        %
# 18549941          9999.0        >100        %
# 18983364          9999.0        >100        %
# 19279147          9999.0        >5.5  Unknown
# 19804257          9999.0        >100        %

# %%
# Remove rows with extreme values
lab_data = lab_data[~extreme_values]

lab_data.head()
# Out:
#    patient_id  case_id    test_name test_abbr  method_number  numeric_result  \
# 0           1   171465      Natrium        Na              1           138.0
# 1           1   171465       Kalium        KA              3             4.6
# 2           1   171465  Hämolytisch      H-Se             42             4.0
# 3           1   171465    Lipämisch      L-Se             43             3.0
# 4           1   171465    Ikterisch      I-Se             44             1.0
#
#   text_result     unit
# 0         138   mmol/L
# 1         4.6   mmol/L
# 2           4  Unknown
# 3           3  Unknown
# 4           1  Unknown

# %% [markdown]
# # 3. Save cleaned dataset

# %%
lab_data.to_csv(lab_output_path, index=False)
