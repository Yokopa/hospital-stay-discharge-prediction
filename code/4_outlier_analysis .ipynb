# %% [markdown]
# # Predictive Modeling of Hospital Length of Stay and Discharge Type
# # [Step 4: Outliers handling in the merged dataset]
#
# his notebook focuses on identifying and handling outliers in the merged dataset, which includes both laboratory results and clinical data.
# Additional data cleaning steps are also performed.
#
# **Libraries used:**
# - pandas
# - matplotlib
# - seaborn
#
# **Last updated:** March 26, 2025.

# %% [markdown]
# ## 1. Import libraries and load dataset

# %%
# Import data manipulation library
import pandas as pd
import numpy as np
import math

# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define file paths for input dataset 
merged_data_path = "/home/anna/Desktop/Master_thesis/output_data/merged_data" 

# Define output path for cleaned output dataset  
otl_merged_data_path = "/home/anna/Desktop/Master_thesis/output_data/merged_data_otl"

# %%
lab_data_path = "/home/anna/Desktop/Master_thesis/output_data/cleaned_lab_data" 
# Load lab dataset 
lab_data = pd.read_csv(lab_data_path)

# %%
# Load dataset 
merged_data = pd.read_csv(merged_data_path)
display(merged_data)
# Out:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 0                1   171465       Entlassung   f   73                   28
# 1                1   333396       Entlassung   f   73                   34
# 2                2    27091       Entlassung   m   51                   13
# 3                2    36154  Entl.ext.Instit   m   50                   12
# 4                2   142617   Entl. in ex.KH   m   51                    1
# ...            ...      ...              ...  ..  ...                  ...
# 268776      240988   393440       Entlassung   m   79                    2
# 268777      240988   412516       Entlassung   m   79                   10
# 268778      240988   425806  Entl.ext.Instit   m   79                    7
# 268779      240989   393141       Entlassung   m   62                    1
# 268780      240990   415184       Entlassung   f   36                    1
#
#        diagnosis        diagnosis_category  ALAT    AP  ...  RDWn   THZn  \
# 0         A04.70       Infectious diseases  10.0   NaN  ...  18.3  165.0
# 1         K57.22        Digestive diseases  19.0  93.0  ...  18.8   93.0
# 2          T84.5        Injury & poisoning   NaN   NaN  ...  18.9  164.0
# 3          I21.4      Circulatory diseases  38.0  58.0  ...  14.4  131.0
# 4          T84.5        Injury & poisoning  15.0  65.0  ...  17.6  159.0
# ...          ...                       ...   ...   ...  ...   ...    ...
# 268776    K55.21        Digestive diseases  12.0   NaN  ...  13.8  176.0
# 268777    I11.00      Circulatory diseases  11.0   NaN  ...  14.3  151.0
# 268778     M16.7  Musculoskeletal diseases   NaN   NaN  ...  13.2  219.0
# 268779     I49.3      Circulatory diseases   NaN   NaN  ...  13.6  269.0
# 268780     G97.1   Nervous system diseases   NaN   NaN  ...  14.3  226.0
#
#         TNT_hn  TNThsn  Tbga  UREA  pCO2  pH  pO2  tHb
# 0          NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 1          NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 2          NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 3        367.0   367.0   NaN   4.5   NaN NaN  NaN  NaN
# 4          NaN     NaN   NaN   5.2   NaN NaN  NaN  NaN
# ...        ...     ...   ...   ...   ...  ..  ...  ...
# 268776     NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 268777     NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 268778     NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 268779     NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
# 268780     NaN     NaN   NaN   NaN   NaN NaN  NaN  NaN
#
# [268781 rows x 58 columns]

# %% [markdown]
# ## 2. Check outliers and extreme outliers for each lab test

# %%
# Select lab test columns (starting from the 10th column)
lab_test_cols = merged_data.columns[9:]

# Dynamically determine subplot grid size
num_cols = len(lab_test_cols)
num_rows = math.ceil(num_cols / 6) 

plt.figure(figsize=(15, num_rows * 3))  # Scale figure height

for i in range(num_cols):
    plt.subplot(num_rows, 6, i + 1) 
    sns.boxplot(y=merged_data[lab_test_cols[i]])  
    plt.title(lab_test_cols[i]) 
    plt.ylabel('')

plt.tight_layout() 
plt.show()

# %%
pd.set_option('display.max_columns', None) # Diplay all the columns

# %%
def detect_extreme_outliers(df, columns, multiplier=3):
    """
    Detects extreme outliers in the given columns using the IQR method.
    
    Args:
        df (pd.DataFrame): The dataframe to analyze.
        columns (list): List of column names to check for outliers.
        multiplier (float): The multiplier for defining extreme outliers (default is 3 for very extreme).
        
    Returns:
        pd.DataFrame: A dataframe with all extreme outlier rows.
    """
    outlier_rows = pd.DataFrame()
    
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - multiplier * IQR
        upper_bound = Q3 + multiplier * IQR
        
        lower_outliers = df[df[col] < lower_bound].sort_values(by=col, ascending=True)
        upper_outliers = df[df[col] > upper_bound].sort_values(by=col, ascending=False)

        if not lower_outliers.empty:
            print(f"\nExtreme lower outliers detected in {col}:")
            display(lower_outliers)
        
        if not upper_outliers.empty:
            print(f"\nExtreme upper outliers detected in {col}:")
            display(upper_outliers)

        outlier_rows = pd.concat([outlier_rows, lower_outliers, upper_outliers])

    return outlier_rows.drop_duplicates()

# %%
# Example usage:
extreme_outliers = detect_extreme_outliers(merged_data, lab_test_cols)
# Out:
# Extreme upper outliers detected in AP:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 66148        63426    51027       Verstorben   f   52                    6
# 87262        83626   378727       Entlassung   f   68                    2
# 151626      145728   148832   Entl. in ex.KH   m   72                    9
# 169236      163047   256869       Entlassung   m   66                    4
# 32878        31452   132149       Entlassung   f   68                   10
# ...            ...      ...              ...  ..  ...                  ...
# 30414        29197   380742       Entlassung   f   85                    2
# 24027        22930   299927       Verstorben   f   92                    0
# 170898      164712   189567       Entlassung   m   61                    1
# 62277        59703    60834  Entl.ext.Instit   m   90                   10
# 205548      197791    67252   Entl. in ex.KH   m   64                    4
#
#        diagnosis            diagnosis_category   ALAT      AP   ASAT  BASm#n  \
# 66148      C78.7                     Neoplasms   57.0  4283.0  280.0     NaN
# 87262     T85.51            Injury & poisoning   93.0  3956.0   86.0    0.07
# 151626     C79.5                     Neoplasms    4.0  3803.0   36.0    0.01
# 169236     K83.1            Digestive diseases  209.0  3521.0  249.0    0.05
# 32878      C24.0                     Neoplasms   38.0  3203.0   61.0     NaN
# ...          ...                           ...    ...     ...    ...     ...
# 30414        R11  Symptoms & abnormal findings   28.0   265.0   45.0    0.03
# 24027      C18.7                     Neoplasms   14.0   265.0   25.0    0.02
# 170898     C22.0                     Neoplasms  137.0   265.0   52.0    0.06
# 62277        A46           Infectious diseases   14.0   265.0   41.0    0.06
# 205548     D50.0      Blood & immune disorders   31.0   265.0   37.0    0.03
#
#           BIg    CA  CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn     GGT  \
# 66148   128.0   NaN NaN    NaN  115.0  200.0     NaN    47.0  3.20  1053.0
# 87262    15.0  2.35 NaN    NaN   56.0    7.0    0.00    92.0  3.63   838.0
# 151626   11.0  2.05 NaN    NaN   39.0  167.0    0.04   112.0  2.64   129.0
# 169236  275.0  2.14 NaN    NaN   60.0   47.0    0.03   100.0  3.06  2770.0
# 32878    43.0   NaN NaN    NaN   59.0   44.0     NaN    91.0   NaN  2747.0
# ...       ...   ...  ..    ...    ...    ...     ...     ...   ...     ...
# 30414     9.0  2.20 NaN    NaN   37.0    9.0    0.02    94.0  3.57   266.0
# 24027    11.0  2.02 NaN    NaN    NaN   32.0    0.00     NaN  3.69   370.0
# 170898   28.0  2.32 NaN    NaN   69.0   35.0    0.30    97.0  3.78   561.0
# 62277     3.0  2.18 NaN    NaN  162.0  312.0    0.15    29.0  3.29   263.0
# 205548   70.0  1.79 NaN    NaN   61.0   38.0    0.40   100.0  2.37   276.0
#
#            GL     H  H-Se    Hbn   Hkn     I  I-Se  IGm#n  INRiH   KA     L  \
# 66148    1.07   4.0   NaN   81.0  0.28   9.0   NaN    NaN   1.35  4.1  19.0
# 87262   10.64  20.0  21.0   90.0  0.26   1.0   1.0   0.09   1.10  3.3  18.0
# 151626   5.27   1.0   0.0   89.0  0.24   1.0   1.0    NaN   1.38  3.2  25.0
# 169236   4.54   3.0   NaN   88.0  0.25  18.0   NaN   0.04   1.25  4.4  40.0
# 32878    5.80   2.0   NaN    NaN   NaN  50.0   NaN    NaN   1.06  3.6  13.0
# ...       ...   ...   ...    ...   ...   ...   ...    ...    ...  ...   ...
# 30414    6.16   NaN   NaN  112.0  0.33   NaN   NaN    NaN   1.04  3.5   NaN
# 24027    5.71  41.0   NaN  108.0  0.32   1.0   NaN   0.05   0.94  3.1   4.0
# 170898  10.50  11.0   NaN   98.0  0.30   2.0   NaN   0.08   1.07  4.5  13.0
# 62277    8.50  10.0   9.0   95.0  0.34   0.0   0.0   0.69   1.97  3.8   7.0
# 205548   5.61   6.0   NaN   82.0  0.24   5.0   NaN   0.18   1.22  3.7  14.0
#
#         L-Se  LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  \
# 66148    NaN   9.3     NaN   3.83  303.0  25.0   83.0     NaN  11.0   NaN
# 87262   48.0   1.3    3.13  10.20  344.0  29.0   82.0    0.87  10.1   NaN
# 151626   6.0   NaN    0.71   5.96  313.0  29.0   92.0    0.39   7.5   NaN
# 169236   NaN   0.7    0.56   6.41  331.0  29.0   87.0    0.66  11.5   NaN
# 32878    NaN   NaN     NaN    NaN    NaN   NaN    NaN     NaN   NaN   NaN
# ...      ...   ...     ...    ...    ...   ...    ...     ...   ...   ...
# 30414    NaN   NaN    0.44   4.23  341.0  31.0   92.0    0.25   9.7   NaN
# 24027    NaN   1.3    0.34   9.48  335.0  29.0   87.0    0.20   9.1   NaN
# 170898   NaN   0.8    0.45   4.87  327.0  26.0   79.0    0.37   9.9   NaN
# 62277    3.0   1.7    0.70  11.70  325.0  29.0   89.0    0.99   9.2   NaN
# 205548   NaN   1.7    1.49  13.60  336.0  34.0  103.0    0.86  11.4   NaN
#
#         NEUm#n  NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  \
# 66148      NaN     2.1  128.0   52.4    14.5  22.8  152.0     NaN     NaN
# 87262     6.12     0.2  137.0   77.8    12.0  20.1  527.0     NaN     NaN
# 151626    3.74     NaN  137.0   52.7     NaN  16.1  263.0     NaN     NaN
# 169236    5.38     0.1  132.0   60.5    13.1  16.4  475.0     NaN     NaN
# 32878      NaN     NaN  140.0   87.9     NaN   NaN    NaN     NaN     NaN
# ...        ...     ...    ...    ...     ...   ...    ...     ...     ...
# 30414     3.49     NaN  135.0   94.6     NaN  14.1  210.0     NaN     NaN
# 24027     8.87     0.0  139.0  115.4    10.3  14.9  557.0     NaN     NaN
# 170898    3.61     0.2  133.0   86.1    11.4  17.6  326.0     NaN     NaN
# 62277     9.04     0.2  139.0   46.6    15.1  15.7  492.0     NaN     NaN
# 205548    7.16     0.0  138.0   61.7    13.0  27.4  194.0     NaN     NaN
#
#         Tbga  UREA  pCO2     pH   pO2  tHb
# 66148   37.0   NaN  28.0  7.237  38.0  NaN
# 87262    NaN   9.0   NaN    NaN   NaN  NaN
# 151626   NaN   3.2   NaN    NaN   NaN  NaN
# 169236   NaN   NaN   NaN    NaN   NaN  NaN
# 32878    NaN   4.5   NaN    NaN   NaN  NaN
# ...      ...   ...   ...    ...   ...  ...
# 30414    NaN   2.1   NaN    NaN   NaN  NaN
# 24027    NaN   NaN   NaN    NaN   NaN  NaN
# 170898   NaN   NaN   NaN    NaN   NaN  NaN
# 62277    NaN  10.9   NaN    NaN   NaN  NaN
# 205548   NaN   NaN   NaN    NaN   NaN  NaN
#
# [4240 rows x 58 columns]
# Extreme upper outliers detected in ASAT:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 175402      169071   332397       Verstorben   m   59                    0
# 44244        42485   206496   Entl. in ex.KH   m   51                    8
# 220319      211585     5583   Entl. in ex.KH   f   46                    6
# 176203      169895   148574   Entl. in ex.KH   f   75                    1
# 200283      192877   295171       Verstorben   f   33                   11
# ...            ...      ...              ...  ..  ...                  ...
# 128289      122973   289337       Verstorben   m   86                    3
# 91509        87757   141148  Entl.ext.Instit   m   34                    1
# 7543          7178   360805   Entl. in ex.KH   f   65                    6
# 157939      151789   111144       Entlassung   f   29                   21
# 159888      153656   134341       Entlassung   m   59                    5
#
#        diagnosis      diagnosis_category    ALAT     AP     ASAT  BASm#n  \
# 175402     T82.8      Injury & poisoning  8857.0    NaN  23743.0    0.05
# 44244      I23.5    Circulatory diseases  3265.0    NaN  22589.0     NaN
# 220319     K72.0      Digestive diseases  4709.0  169.0  21617.0     NaN
# 176203    I50.01    Circulatory diseases  4495.0    NaN  16969.0     NaN
# 200283     I46.0    Circulatory diseases  8127.0    NaN  15186.0     NaN
# ...          ...                     ...     ...    ...      ...     ...
# 128289    I50.01    Circulatory diseases   351.0  346.0    100.0     NaN
# 91509      F10.4        Mental disorders    64.0   61.0    100.0    0.05
# 7543       I63.8    Circulatory diseases    31.0    NaN    100.0     NaN
# 157939     O72.1  Pregnancy & childbirth    10.0    NaN    100.0    0.02
# 159888    K80.31      Digestive diseases   170.0    NaN    100.0     NaN
#
#           BIg    CA      CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn    GGT  \
# 175402   50.0   NaN  1499.0    0.7   85.0   25.0    0.01    86.0  3.45   42.0
# 44244    34.0   NaN   702.0    0.2  252.0  141.0     NaN    24.0  2.63  130.0
# 220319   68.0   NaN   294.0    0.9  204.0   15.0     NaN     NaN   NaN  124.0
# 176203   28.0   NaN   159.0    0.6  196.0  107.0     NaN    21.0  3.83   64.0
# 200283   25.0   NaN   234.0    0.7  105.0   31.0     NaN    66.0  4.59   44.0
# ...       ...   ...     ...    ...    ...    ...     ...     ...   ...    ...
# 128289   13.0   NaN     NaN    NaN  188.0   36.0     NaN    27.0  3.89  165.0
# 91509    17.0  2.49   563.0    NaN   93.0   16.0    0.13    92.0  3.86  368.0
# 7543      3.0  2.09  3482.0    1.2   60.0   27.0     NaN    92.0  3.69   11.0
# 157939    7.0   NaN   396.0    1.6   80.0   12.0    0.03    86.0  2.20    9.0
# 159888  114.0   NaN     NaN    1.7   53.0  213.0     NaN   110.0  3.13    NaN
#
#           GL     H  H-Se    Hbn   Hkn     I  I-Se  IGm#n  INRiH   KA     L  \
# 175402   0.3  40.0   NaN  114.0  0.34   4.0   NaN   0.17    NaN  5.8  12.0
# 44244    5.8  91.0   NaN   88.0  0.32   2.0   NaN    NaN   1.65  4.3   9.0
# 220319  10.8   5.0   NaN    NaN   NaN  56.0   NaN    NaN    NaN  3.5  13.0
# 176203   7.2  50.0   NaN  132.0  0.35   2.0   NaN    NaN   1.58  4.2   8.0
# 200283   5.4   8.0   NaN   94.0  0.40   2.0   NaN    NaN   1.59  3.5   9.0
# ...      ...   ...   ...    ...   ...   ...   ...    ...    ...  ...   ...
# 128289   NaN   3.0   5.0  118.0  0.39   1.0   1.0    NaN   1.21  4.4   4.0
# 91509    4.7  17.0  11.0  133.0  0.38   1.0   1.0   0.06   0.92  3.1   6.0
# 7543     7.1   6.0   8.0  104.0  0.30   0.0   1.0    NaN   1.10  4.7   9.0
# 157939   5.1  10.0  15.0   61.0  0.18   1.0   1.0   0.12   1.01  4.3   1.0
# 159888   6.4   2.0   NaN   94.0  0.27   8.0   NaN    NaN   1.54  3.3  11.0
#
#         L-Se  LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  \
# 175402   NaN  16.0    0.70  13.80  334.0  33.0   99.0    0.79  10.4   0.9
# 44244    NaN   4.2     NaN  15.20  359.0  34.0   96.0     NaN  11.4   1.3
# 220319   NaN   NaN     NaN    NaN    NaN   NaN    NaN     NaN   NaN   NaN
# 176203   NaN  14.0     NaN  26.00  308.0  32.0   90.0     NaN  10.2   0.3
# 200283   NaN   3.5     NaN  10.60  311.0  26.0   78.0     NaN  10.2   0.8
# ...      ...   ...     ...    ...    ...   ...    ...     ...   ...   ...
# 128289   2.0   NaN     NaN  13.70  299.0  30.0  101.0     NaN  11.5   NaN
# 91509    2.0   2.2    1.98   7.01  349.0  34.0   99.0    1.03  11.3   NaN
# 7543     2.0   0.7     NaN   9.58  338.0  31.0   90.0     NaN  10.2   0.4
# 157939   4.0   1.9    0.82  15.00  358.0  30.0   83.0    0.73  10.2   0.5
# 159888   NaN   1.3     NaN  25.30  349.0  30.0   86.0     NaN  10.9   0.4
#
#         NEUm#n  NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  \
# 175402   12.09     0.2  140.0    NaN     NaN  12.5   57.0   328.0   328.0
# 44244      NaN     0.2  137.0   41.1    22.5  12.5  161.0     NaN     NaN
# 220319     NaN     NaN  130.0    NaN     NaN   NaN    NaN     NaN     NaN
# 176203     NaN     6.1  134.0   36.9    17.3  12.5  204.0   130.0   149.0
# 200283     NaN     0.1  139.0   41.7    17.9  14.6  205.0    63.6    63.6
# ...        ...     ...    ...    ...     ...   ...    ...     ...     ...
# 128289     NaN     0.9  164.0   64.0     NaN  17.0  199.0     NaN     NaN
# 91509     3.76     0.1  134.0  125.7     9.8  11.8  113.0     NaN     NaN
# 7543       NaN     0.0  134.0   77.8    11.5  12.7  231.0    70.8    70.8
# 157939   13.31     0.1  131.0   97.9    11.0  15.6   41.0   121.0   121.0
# 159888     NaN     0.0  137.0   44.5    16.6  14.9  225.0     NaN     NaN
#
#         Tbga  UREA  pCO2     pH   pO2    tHb
# 175402  37.0   5.4  27.0  7.141  84.0   84.0
# 44244   35.1  16.3  38.0  7.356  36.0   91.0
# 220319  37.2   8.1  38.0    NaN  87.0  116.0
# 176203  34.8  14.3  38.0  7.486  80.0  112.0
# 200283  36.7   9.0  27.0  7.450  76.0   95.0
# ...      ...   ...   ...    ...   ...    ...
# 128289   NaN  29.4   NaN    NaN   NaN    NaN
# 91509    NaN   NaN   NaN    NaN   NaN    NaN
# 7543    36.2   8.0  46.0  7.416  82.0  105.0
# 157939  36.6   3.1  44.0  7.240  85.0   74.0
# 159888  36.9   5.5  32.0  7.435  79.0   96.0
#
# [8872 rows x 58 columns]
# Extreme upper outliers detected in BASm#n:
#         patient_id  case_id discharge_type sex  age  length_of_stay_days  \
# 125113      119859   294343     Entlassung   m   38                    4
# 204352      196682    45078     Entlassung   m   47                    2
# 188941      182019   300766     Entlassung   m   46                    3
# 119539      114554   361777     Entlassung   f   43                    3
# 251965      233326   413613     Entlassung   m   71                    3
# ...            ...      ...            ...  ..  ...                  ...
# 182152      175552   294230     Entlassung   f   71                    3
# 184854      178177   130962     Entlassung   f   77                    1
# 186019      179218   378662     Entlassung   f   66                    6
# 51137        48976   176668     Entlassung   m   85                    6
# 268209      240769   403434     Entlassung   m   70                   11
#
#        diagnosis        diagnosis_category   ALAT      AP  ASAT  BASm#n   BIg  \
# 125113    C92.10                 Neoplasms  101.0    64.0  49.0    5.10   8.0
# 204352    C92.10                 Neoplasms   48.0     NaN   NaN    3.46  11.0
# 188941    C92.10                 Neoplasms   39.0    82.0  41.0    3.21   9.0
# 119539    C92.10                 Neoplasms   18.0    64.0  22.0    1.87   9.0
# 251965     N20.0    Genitourinary diseases    NaN     NaN   NaN    1.71   NaN
# ...          ...                       ...    ...     ...   ...     ...   ...
# 182152     C34.3                 Neoplasms   38.0  1383.0  57.0    0.15   5.0
# 184854     C83.3                 Neoplasms   15.0    83.0  15.0    0.15   NaN
# 186019    M54.87  Musculoskeletal diseases    NaN     NaN   NaN    0.15   NaN
# 51137     I50.01      Circulatory diseases   36.0   201.0  61.0    0.15  14.0
# 268209    I50.14      Circulatory diseases    NaN     NaN   NaN    0.15   NaN
#
#           CA     CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn    GGT    GL  \
# 125113  2.34    NaN    NaN  100.0    2.0    1.43    90.0  3.78   36.0  7.20
# 204352  2.37  264.0    NaN   84.0    NaN    1.10    95.0  4.15   42.0  5.80
# 188941  2.20    NaN    NaN   60.0   15.0    0.81   102.0  3.66   95.0  7.90
# 119539  2.20    NaN    NaN   57.0  257.0    0.29   109.0  3.80   37.0  6.95
# 251965  2.39    NaN    NaN   92.0    0.0    0.74    72.0  4.81    NaN   NaN
# ...      ...    ...    ...    ...    ...     ...     ...   ...    ...   ...
# 182152  1.88   18.0    NaN   53.0   87.0    0.82    92.0  3.35  927.0  8.60
# 184854  2.13    NaN    NaN   55.0    NaN    0.03    87.0  3.46   27.0  5.53
# 186019   NaN    NaN    NaN    NaN    NaN    0.25     NaN  3.98    NaN   NaN
# 51137   2.29  428.0    NaN  219.0   26.0    6.32    22.0  4.07  694.0  5.70
# 268209   NaN    NaN    NaN  111.0   10.0    0.00    58.0  4.50    NaN   NaN
#
#            H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 125113  29.0   NaN  118.0  0.35  1.0   NaN  46.89   1.02  3.8  10.0   NaN
# 204352  11.0   9.0  123.0  0.37  1.0   1.0  25.49   1.06  3.8  11.0  10.0
# 188941   8.0   NaN  126.0  0.33  1.0   NaN  24.91   1.11  3.1  20.0   NaN
# 119539   8.0   NaN  108.0  0.33  1.0   NaN  19.08   1.29  3.8   3.0   NaN
# 251965  27.0   NaN  145.0  0.44  1.0   NaN   6.52   1.08  5.0  48.0   NaN
# ...      ...   ...    ...   ...  ...   ...    ...    ...  ...   ...   ...
# 182152   7.0   NaN  102.0  0.32  0.0   NaN   0.80   1.09  3.7   9.0   NaN
# 184854   6.0   NaN  102.0  0.29  1.0   NaN   0.58    NaN  3.8   7.0   NaN
# 186019   NaN   NaN  122.0  0.35  NaN   NaN   0.01    NaN  NaN   NaN   NaN
# 51137   20.0  54.0  127.0  0.38  1.0   1.0   0.06   1.37  4.8   6.0   4.0
# 268209  12.0   NaN  135.0  0.39  1.0   NaN   0.98    NaN  4.4  10.0   NaN
#
#         LACT  LYMm#n   Leukn  MCHCn  MCHn  MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 125113   1.5    8.57  134.00  334.0  28.0  86.0    2.04   9.9   NaN   93.06
# 204352   2.0    5.51   86.10  338.0  30.0  87.0    3.63  10.3   NaN   46.99
# 188941   5.1    3.71  102.00  369.0  35.0  95.0    4.77  11.6   NaN   65.55
# 119539   NaN    2.08   89.70  331.0  28.0  86.0    2.91  11.3   NaN   63.55
# 251965   NaN    3.48   26.10  330.0  30.0  92.0    0.56   9.5   NaN   13.18
# ...      ...     ...     ...    ...   ...   ...     ...   ...   ...     ...
# 182152   1.7    0.41   32.70  324.0  30.0  94.0    0.87  10.3   NaN   29.65
# 184854   NaN    0.37   10.50  347.0  30.0  85.0    0.60  10.3   NaN    8.85
# 186019   NaN    1.90    5.92  347.0  31.0  88.0    0.69  11.0   NaN    2.92
# 51137    2.4    1.66   12.10  329.0  31.0  95.0    0.77  11.0   NaN    3.14
# 268209   NaN    0.94   14.80  344.0  30.0  87.0    0.66   9.9   NaN   12.13
#
#         NRBCmn     Na  QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  \
# 125113     0.8  142.0  96.2    10.7  16.4   92.0     NaN     NaN   NaN   NaN
# 204352     0.5  138.0  87.0    11.1  17.6  164.0     NaN     NaN   NaN   4.8
# 188941     0.0  125.0  69.9    12.0  14.2  235.0     NaN     NaN   NaN   4.5
# 119539     0.2  140.0  57.2    13.5  15.4  324.0     NaN     NaN   NaN   2.8
# 251965     0.1  142.0  83.7    11.2  16.4  824.0     NaN     NaN  37.0   9.0
# ...        ...    ...   ...     ...   ...    ...     ...     ...   ...   ...
# 182152     0.1  141.0  82.0    11.5  19.0  180.0    20.5    24.4   NaN   NaN
# 184854     0.2  140.0   NaN     NaN  18.5  210.0     NaN     NaN   NaN   4.6
# 186019     0.0    NaN   NaN     NaN  13.1  161.0     NaN     NaN   NaN   NaN
# 51137      0.1  145.0  51.7    14.4  15.9  156.0   250.0   228.0   NaN  19.2
# 268209     0.0  143.0   NaN     NaN  17.8  196.0     NaN     NaN   NaN   NaN
#
#         pCO2     pH   pO2  tHb
# 125113   NaN    NaN   NaN  NaN
# 204352   NaN    NaN   NaN  NaN
# 188941   NaN    NaN   NaN  NaN
# 119539   NaN    NaN   NaN  NaN
# 251965  41.0  7.406  43.0  NaN
# ...      ...    ...   ...  ...
# 182152   NaN    NaN   NaN  NaN
# 184854   NaN    NaN   NaN  NaN
# 186019   NaN    NaN   NaN  NaN
# 51137    NaN    NaN   NaN  NaN
# 268209   NaN    NaN   NaN  NaN
#
# [512 rows x 58 columns]
# Extreme upper outliers detected in BIg:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 82602        79110    82052       Verstorben   f   72                    1
# 48496        46573   150052   Entl. in ex.KH   m   66                    3
# 149903      144086   368314   Entl. in ex.KH   f   60                    6
# 61569        58980     4536       Verstorben   m   66                   14
# 152018      146113    26896   Entl. in ex.KH   m   75                    3
# ...            ...      ...              ...  ..  ...                  ...
# 29541        28361   375764       Entlassung   m   70                    2
# 179647      173051   263007  Entl.ext.Instit   m   68                   30
# 73225        70147    64859   Entl. in ex.KH   f   80                    0
# 180295      173691   214409       Entlassung   m   84                    5
# 122715      117579   128356   Entl. in ex.KH   m   43                    0
#
#        diagnosis    diagnosis_category    ALAT      AP    ASAT  BASm#n    BIg  \
# 82602      K71.0    Digestive diseases    28.0    26.0   228.0     NaN  781.0
# 48496      K74.6    Digestive diseases  1507.0  1384.0  8628.0    0.05  729.0
# 149903     C22.1             Neoplasms   393.0  1901.0   531.0     NaN  674.0
# 61569      K70.3    Digestive diseases    34.0   126.0    60.0     NaN  660.0
# 152018       C19             Neoplasms    50.0   383.0    65.0    0.10  653.0
# ...          ...                   ...     ...     ...     ...     ...    ...
# 29541      C22.0             Neoplasms   100.0   552.0   339.0     NaN   39.0
# 179647    I50.14  Circulatory diseases    21.0   114.0    39.0    0.02   39.0
# 73225     K80.30    Digestive diseases   697.0   226.0   429.0    0.03   39.0
# 180295    I50.14  Circulatory diseases    29.0   167.0    32.0     NaN   39.0
# 122715     I46.0  Circulatory diseases    70.0     NaN    43.0     NaN   39.0
#
#           CA     CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn     GGT     GL  \
# 82602   2.39  165.0    1.7  148.0   22.0     NaN    20.0  1.39   178.0   5.79
# 48496   2.38   50.0    1.5  199.0   35.0    0.04    23.0  4.33   282.0   9.30
# 149903   NaN    NaN    NaN   98.0    NaN     NaN    54.0  3.10   958.0    NaN
# 61569   2.14    NaN    NaN  206.0   12.0     NaN    27.0   NaN    28.0   9.50
# 152018  1.88    NaN    NaN  153.0   55.0    0.20    33.0  2.32   196.0    NaN
# ...      ...    ...    ...    ...    ...     ...     ...   ...     ...    ...
# 29541    NaN    NaN    NaN  173.0   26.0     NaN    34.0  3.78   422.0    NaN
# 179647  2.43    NaN    2.5  252.0  133.0    0.00    22.0  3.24   279.0   7.20
# 73225   2.38    NaN    NaN   84.0  200.0    0.10    57.0  3.63  1034.0  10.94
# 180295   NaN    NaN    NaN   93.0   12.0     NaN    65.0  4.41   290.0   6.99
# 122715   NaN  137.0    NaN   76.0    2.0     NaN   106.0  5.27    48.0   5.50
#
#             H  H-Se    Hbn   Hkn      I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 82602   107.0  78.0   56.0  0.17   64.0  66.0    NaN   3.81  5.8  54.0  53.0
# 48496     2.0  52.0  145.0  0.40   59.0  58.0   0.26   2.08  4.1  32.0  26.0
# 149903    0.0   NaN   96.0  0.26   54.0   NaN    NaN   1.13  4.1  34.0   NaN
# 61569     0.0   NaN    NaN   NaN  888.0   NaN    NaN   1.55  4.1  32.0   NaN
# 152018    0.0   0.0   58.0  0.16   50.0  53.0   0.12   1.19  2.9  29.0  33.0
# ...       ...   ...    ...   ...    ...   ...    ...    ...  ...   ...   ...
# 29541     5.0  13.0  114.0  0.32    3.0   4.0    NaN   1.20  4.7  13.0  22.0
# 179647    4.0   2.0   97.0  0.29    2.0   3.0   0.10   1.87  4.2  11.0   6.0
# 73225     5.0   NaN  113.0  0.32    3.0   NaN   0.03   1.09  3.5  23.0   NaN
# 180295  181.0   NaN  145.0  0.42    3.0   NaN    NaN   1.38  4.7   6.0   NaN
# 122715    8.0   NaN  152.0  0.45    3.0   NaN    NaN   0.99  4.1  10.0   NaN
#
#         LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 82602    3.1     NaN  17.40  326.0  33.0   92.0     NaN  10.9   1.5     NaN
# 48496   10.8    0.46   8.48  360.0  33.0   92.0    0.98  13.5   0.4    6.69
# 149903   NaN     NaN  11.60  364.0  31.0   85.0     NaN   8.2   NaN     NaN
# 61569    NaN     NaN    NaN    NaN   NaN    NaN     NaN   NaN   NaN     NaN
# 152018   NaN    0.17  10.20  371.0  38.0  102.0    0.64  11.1   NaN    5.99
# ...      ...     ...    ...    ...   ...    ...     ...   ...   ...     ...
# 29541    NaN     NaN   9.53  336.0  30.0   92.0     NaN  10.2   NaN     NaN
# 179647   0.8    0.41   8.07  316.0  29.0   90.0    0.92  11.0   0.7   15.73
# 73225    NaN    1.13  10.00  352.0  31.0   88.0    0.48   9.6   NaN    8.29
# 180295   NaN     NaN   5.15  347.0  33.0   95.0     NaN  11.7   NaN     NaN
# 122715   1.6     NaN   9.91  339.0  29.0   85.0     NaN  10.8   NaN     NaN
#
#         NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  \
# 82602      1.6  139.0   18.1    35.3  14.8  100.0    51.3    51.3  36.2  17.9
# 48496      0.0  130.0   31.1    29.2  21.7  120.0     NaN     NaN  34.8  16.5
# 149903     0.0  122.0   74.8    11.9  19.8  130.0     NaN     NaN   NaN  10.3
# 61569      NaN  136.0   43.1     NaN   NaN    NaN     NaN     NaN  37.0  15.9
# 152018     0.0  136.0   63.2    12.8  15.0  152.0     NaN     NaN   NaN   NaN
# ...        ...    ...    ...     ...   ...    ...     ...     ...   ...   ...
# 29541      0.0  143.0   65.0    12.4  17.2  266.0     NaN     NaN   NaN  13.8
# 179647     0.1  137.0   27.4    18.9  27.8  111.0     NaN     NaN  35.0  28.3
# 73225      NaN  133.0   86.6   111.0  13.1  193.0     NaN     NaN   NaN   9.6
# 180295     0.0  140.0   50.6    14.8  15.6  138.0    78.5    79.6   NaN   7.5
# 122715     0.0  136.0  104.6    10.5  11.8  194.0     3.0     3.0  36.8   5.0
#
#         pCO2     pH    pO2    tHb
# 82602   33.0  7.325   77.0   46.0
# 48496   25.0  7.277   79.0  142.0
# 149903   NaN    NaN    NaN    NaN
# 61569   26.0  7.306   37.0    NaN
# 152018   NaN    NaN    NaN    NaN
# ...      ...    ...    ...    ...
# 29541    NaN    NaN    NaN    NaN
# 179647  42.0  7.390  111.0   96.0
# 73225    NaN    NaN    NaN  119.0
# 180295   NaN    NaN    NaN    NaN
# 122715  43.0  7.390    NaN    NaN
#
# [4254 rows x 58 columns]
# Extreme lower outliers detected in CA:
#         patient_id  case_id  discharge_type sex  age  length_of_stay_days  \
# 247483      231400   405775      Entlassung   f   78                    4
# 76707        73350   351582  Entl. in ex.KH   m   62                    2
# 95616        91617   184151      Entlassung   m   80                    3
# 93826        89815   149807      Entlassung   m   70                   10
# 5613          5373   278026      Entlassung   f   89                    4
# ...            ...      ...             ...  ..  ...                  ...
# 213768      205599   386047      Verstorben   m   46                    2
# 108120      103585    90397      Entlassung   m   71                    2
# 129496      124112   193022      Entlassung   m   68                    4
# 171031      164842   228951  Entl. in ex.KH   m   81                    7
# 473            427    14067  Entl. in ex.KH   f   52                    1
#
#        diagnosis      diagnosis_category   ALAT     AP    ASAT  BASm#n   BIg  \
# 247483     C54.1               Neoplasms    NaN    NaN    24.0    0.02  10.0
# 76707      I63.5    Circulatory diseases    NaN    NaN    17.0     NaN   NaN
# 95616      C15.5               Neoplasms   44.0   93.0    39.0     NaN   NaN
# 93826      A41.9     Infectious diseases    NaN  486.0    20.0     NaN  94.0
# 5613       K52.8      Digestive diseases   11.0   19.0    24.0     NaN  13.0
# ...          ...                     ...    ...    ...     ...     ...   ...
# 213768    A41.51     Infectious diseases  460.0    NaN  1375.0     NaN   6.0
# 108120     T82.8      Injury & poisoning    NaN    NaN     NaN    0.03   NaN
# 129496     N30.2  Genitourinary diseases    NaN    NaN     NaN     NaN   NaN
# 171031     E83.4   Endocrine & metabolic   12.0   95.0    15.0     NaN  13.0
# 473       K57.11      Digestive diseases   18.0   95.0    17.0     NaN  14.0
#
#           CA     CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn   GGT    GL  \
# 247483 -0.11    NaN    NaN   65.0    1.0    0.06    80.0  4.54  62.0  4.83
# 76707  -0.04  120.0    NaN   54.0    1.0     NaN   107.0  4.75  35.0  4.90
# 95616  -0.03    NaN    NaN  147.0    0.0     NaN    38.0  3.97  36.0  8.20
# 93826  -0.02    NaN    NaN  243.0  157.0     NaN    22.0  2.58   NaN   NaN
# 5613    0.04   42.0    1.0  218.0    1.0     NaN    27.0  4.57  14.0  4.60
# ...      ...    ...    ...    ...    ...     ...     ...   ...   ...   ...
# 213768  1.64  312.0    0.5  149.0  179.0     NaN    81.0  3.65  32.0  4.80
# 108120  1.64    NaN    NaN  990.0   26.0    0.27     4.0  3.26   NaN   NaN
# 129496  1.64    NaN    NaN  386.0    9.0     NaN    13.0  3.69   NaN   NaN
# 171031  1.64  303.0    NaN  137.0   23.0     NaN    41.0  3.58  28.0  7.68
# 473     1.64    NaN    1.7   33.0   67.0     NaN   123.0  2.99  70.0  4.60
#
#            H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 247483  14.0   NaN  125.0  0.37  1.0   NaN   0.03   1.09  4.0   8.0   NaN
# 76707   10.0   6.0  148.0  0.44  1.0   1.0    NaN   1.04  4.1   7.0   9.0
# 95616    7.0   NaN  118.0  0.34  1.0   NaN    NaN   1.14  4.4  13.0   NaN
# 93826    8.0   NaN   65.0  0.22  6.0   NaN    NaN    NaN  3.9  23.0   NaN
# 5613    34.0   NaN  125.0  0.37  1.0   NaN    NaN   1.06  5.3  13.0   NaN
# ...      ...   ...    ...   ...  ...   ...    ...    ...  ...   ...   ...
# 213768  18.0   NaN  113.0  0.31  1.0   NaN    NaN   1.30  4.1   7.0   NaN
# 108120   9.0   NaN  115.0  0.33  0.0   NaN   0.03   1.03  5.9  10.0   NaN
# 129496   7.0   NaN  114.0  0.34  1.0   NaN    NaN   1.16  5.1  12.0   NaN
# 171031   9.0   NaN  123.0  0.36  1.0   NaN    NaN   1.51  3.8   8.0   NaN
# 473      8.0   NaN  122.0  0.26  1.0   NaN    NaN   1.00  3.7  10.0   NaN
#
#         LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 247483   NaN    1.47   6.10  341.0  28.0   81.0    0.45   9.4   NaN    4.07
# 76707    1.1     NaN   7.16  336.0  31.0   93.0     NaN   9.0   NaN     NaN
# 95616    NaN     NaN   6.88  345.0  30.0   87.0     NaN   9.0   NaN     NaN
# 93826    NaN     NaN  19.30  341.0  29.0   83.0     NaN   NaN   NaN     NaN
# 5613     2.6     NaN   8.31  334.0  30.0   87.0     NaN  10.3   0.5     NaN
# ...      ...     ...    ...    ...   ...    ...     ...   ...   ...     ...
# 213768   6.2     NaN   1.04  366.0  33.0   97.0     NaN   9.1   0.7     NaN
# 108120   NaN    2.28   7.88  344.0  35.0  102.0    0.61  10.0   NaN    4.66
# 129496   NaN     NaN  11.60  334.0  31.0   92.0     NaN  11.2   NaN     NaN
# 171031   NaN     NaN  12.30  345.0  35.0   99.0     NaN  11.8   NaN     NaN
# 473      0.3     NaN   9.07  351.0  31.0   87.0     NaN   9.3   0.8     NaN
#
#         NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  \
# 247483     0.0  135.0   83.3    11.8  13.3  188.0     NaN     NaN   NaN   NaN
# 76707      0.0  138.0   91.5    11.1  12.4  301.0    7.33    7.33  37.0   5.6
# 95616      0.0  133.0   73.9    12.4  12.5  188.0     NaN     NaN   NaN   8.7
# 93826      0.3  131.0    NaN     NaN  23.6   68.0     NaN     NaN  37.0  40.4
# 5613       0.0  140.0   88.4    11.3  12.6  221.0     NaN     NaN  37.0  26.7
# ...        ...    ...    ...     ...   ...    ...     ...     ...   ...   ...
# 213768     0.9  129.0   87.5    11.5  14.6   80.0    9.85    9.85  36.2   8.9
# 108120     0.0  132.0   94.6    10.9  13.5  130.0     NaN     NaN  37.0  37.9
# 129496     0.0  145.0   71.4    12.3  15.0  279.0     NaN     NaN   NaN  31.5
# 171031     0.0  142.0   45.6    16.3  13.2  172.0     NaN     NaN   NaN   NaN
# 473        0.1  140.0  103.0    10.7  13.6  219.0     NaN     NaN  36.7   2.3
#
#         pCO2     pH   pO2    tHb
# 247483   NaN    NaN   NaN    NaN
# 76707    NaN  7.410   NaN    NaN
# 95616    NaN    NaN   NaN    NaN
# 93826   25.0  7.333  25.0    NaN
# 5613    41.0  7.345  20.0  132.0
# ...      ...    ...   ...    ...
# 213768  51.0  7.078  72.0  114.0
# 108120  29.0  7.220  59.0    NaN
# 129496   NaN    NaN   NaN    NaN
# 171031   NaN    NaN   NaN    NaN
# 473     32.0  7.403  93.0  126.0
#
# [296 rows x 58 columns]
# Extreme upper outliers detected in CA:
#         patient_id  case_id  discharge_type sex  age  length_of_stay_days  \
# 24946        23849   235335      Verstorben   f   57                    1
# 94534        90504    51870  Entl. in ex.KH   m   71                   12
# 248319      231775   409023  Entl. in ex.KH   m   45                    4
# 194096      186819    16410  Entl. in ex.KH   f   75                   10
# 8149          7708   197748      Entlassung   f   58                    5
# ...            ...      ...             ...  ..  ...                  ...
# 127749      122430   385840  Entl. in ex.KH   m   84                   10
# 86999        83388   160128  Entl. in ex.KH   m   61                    1
# 10286         9738   117941  Entl. in ex.KH   f   70                    3
# 88790        85092    74076  Entl. in ex.KH   m   76                    5
# 151141      145279   161779  Entl. in ex.KH   f   69                    0
#
#        diagnosis            diagnosis_category  ALAT     AP   ASAT  BASm#n  \
# 24946      R57.2  Symptoms & abnormal findings  56.0    NaN   97.0     NaN
# 94534        C61                     Neoplasms  15.0   54.0  113.0    0.03
# 248319    M89.58      Musculoskeletal diseases  16.0  129.0   18.0     NaN
# 194096     C50.9                     Neoplasms  48.0  110.0   62.0     NaN
# 8149      C91.10                     Neoplasms  12.0    NaN    NaN     NaN
# ...          ...                           ...   ...    ...    ...     ...
# 127749    E83.58         Endocrine & metabolic   6.0   41.0   10.0    0.02
# 86999      C43.7                     Neoplasms  17.0  194.0   40.0    0.02
# 10286      A08.4           Infectious diseases  17.0  108.0   19.0    0.02
# 88790      K75.0            Digestive diseases  56.0  480.0   64.0    0.04
# 151141    J96.09          Respiratory diseases  13.0  229.0   19.0    0.02
#
#          BIg    CA     CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn     GGT  \
# 24946   59.0  5.37  355.0    1.3  205.0    NaN     NaN    33.0  4.09     NaN
# 94534   13.0  5.24    NaN    1.9  113.0   67.0    0.10    75.0  2.43    21.0
# 248319   6.0  4.85    NaN    NaN    NaN    6.0     NaN     NaN  3.23    72.0
# 194096  19.0  4.79    NaN    NaN  257.0  129.0     NaN    15.0  3.24   143.0
# 8149    10.0  4.37    NaN    NaN   72.0   29.0     NaN    80.0  4.84    21.0
# ...      ...   ...    ...    ...    ...    ...     ...     ...   ...     ...
# 127749   3.0  2.90    NaN    1.0  162.0    9.0    0.28    33.0  4.21    81.0
# 86999   11.0  2.90    NaN    NaN   70.0  225.0    0.07    97.0  5.14   147.0
# 10286    7.0  2.90    NaN    NaN   83.0   82.0    0.02    62.0  4.52    22.0
# 88790    6.0  2.90    NaN    NaN   74.0  102.0    0.54    85.0  3.45  3343.0
# 151141   5.0  2.90    NaN    NaN   63.0   86.0    0.47    87.0  3.74   200.0
#
#            GL     H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  \
# 24946    4.90  16.0   NaN  123.0  0.37  5.0   NaN    NaN   1.38  4.1   6.0
# 94534    6.47   8.0   NaN   67.0  0.19  0.0   NaN   1.30   1.10  3.8   4.0
# 248319   4.83   NaN   3.0  102.0  0.27  NaN   1.0    NaN   1.17  3.3   NaN
# 194096   6.80  25.0  29.0  113.0  0.31  1.0   2.0    NaN   1.35  4.6  11.0
# 8149      NaN   4.0  13.0  139.0  0.42  1.0   1.0    NaN   1.13  3.3  12.0
# ...       ...   ...   ...    ...   ...  ...   ...    ...    ...  ...   ...
# 127749   5.50   6.0  10.0  113.0  0.36  0.0   0.0   0.04   1.00  4.6  10.0
# 86999   14.40   5.0  30.0  157.0  0.46  1.0   1.0   1.30   1.18  4.3  10.0
# 10286    8.70   8.0  12.0  124.0  0.34  1.0   1.0   0.04   0.97  3.6   6.0
# 88790    5.97   3.0   4.0  105.0  0.32  0.0   1.0   0.03   0.95  3.8  11.0
# 151141   6.70   2.0   NaN  112.0  0.35  0.0   NaN   0.12   1.20  3.5   5.0
#
#         L-Se  LACT  LYMm#n  Leukn  MCHCn  MCHn  MCVn  MONm#n  MPVn  MTHB  \
# 24946    NaN   5.2     NaN  20.40  336.0  30.0  90.0     NaN  10.9   0.7
# 94534    NaN   1.2    0.65  10.90  358.0  30.0  83.0    0.61  10.7   0.8
# 248319   3.0   NaN     NaN   5.05  361.0  31.0  87.0     NaN  10.0   NaN
# 194096   6.0   1.9     NaN   7.62  320.0  30.0  91.0     NaN  11.8   NaN
# 8149     6.0   NaN     NaN  22.60  333.0  29.0  86.0     NaN  11.8   NaN
# ...      ...   ...     ...    ...    ...   ...   ...     ...   ...   ...
# 127749   7.0   1.1    1.61  10.70  340.0  29.0  85.0    1.11  12.2   1.1
# 86999    2.0   NaN    1.85  15.10  348.0  30.0  89.0    0.87   9.9   NaN
# 10286    4.0   1.5    0.80   7.40  359.0  28.0  76.0    0.68  10.1   NaN
# 88790    2.0   NaN    0.70  10.30  326.0  30.0  93.0    0.96  10.2   NaN
# 151141   NaN   NaN    2.03   9.23  321.0  30.0  93.0    0.74  11.3   NaN
#
#         NEUm#n  NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  \
# 24946      NaN     0.3  140.0   51.1    14.1  14.6  162.0   555.0   555.0
# 94534     7.48     1.0  146.0   80.1    12.4  14.6   85.0     NaN     NaN
# 248319     NaN     NaN  139.0   71.1     NaN  12.5  243.0     NaN     NaN
# 194096     NaN     2.5  136.0   54.0     NaN  16.4   89.0     NaN     NaN
# 8149       NaN     0.0  139.0   76.2    12.0  14.0  204.0     NaN     NaN
# ...        ...     ...    ...    ...     ...   ...    ...     ...     ...
# 127749    7.65     0.0  131.0  103.0    10.9  15.4  155.0     NaN     NaN
# 86999    11.07     0.2  134.0   67.6    12.6  13.0  206.0     NaN     NaN
# 10286     5.84     0.0  134.0  110.1    10.3  12.8  225.0     NaN     NaN
# 88790     8.07     0.0  138.0  112.8    10.2  15.6  429.0     NaN     NaN
# 151141    5.85     0.0  141.0   65.0    12.4  16.1  199.0     NaN     NaN
#
#         Tbga  UREA  pCO2     pH    pO2    tHb
# 24946   34.8  11.7  64.0  7.213   68.0  113.0
# 94534   37.0   NaN  41.0  7.365  106.0   69.0
# 248319   NaN  13.4   NaN    NaN    NaN  101.0
# 194096   NaN  18.3   NaN    NaN    NaN    NaN
# 8149     NaN   NaN   NaN    NaN    NaN    NaN
# ...      ...   ...   ...    ...    ...    ...
# 127749  37.0   NaN  42.0  7.301   31.0  123.0
# 86999    NaN   9.8   NaN    NaN    NaN  164.0
# 10286    NaN   NaN   NaN    NaN    NaN    NaN
# 88790    NaN   5.5   NaN    NaN    NaN    NaN
# 151141   NaN   4.8   NaN    NaN    NaN    NaN
#
# [275 rows x 58 columns]
# Extreme upper outliers detected in CK:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 16574        15785   111849       Entlassung   f   23                   11
# 238133      227135   410762  Entl.ext.Instit   m   37                   57
# 18622        17725    85564   Entl. in ex.KH   m   57                    9
# 34631        33171   121988       Verstorben   m   51                    3
# 222479      213649   296743   Entl. in ex.KH   f   42                   47
# ...            ...      ...              ...  ..  ...                  ...
# 255808      235033   400175       Entlassung   m   62                    7
# 102929       98538   117660   Entl. in ex.KH   m   47                   10
# 130823      125410   106267       Entlassung   f   76                    5
# 99326        95125   325206       Entlassung   m   72                    8
# 235069      225809   383341       Entlassung   f   92                    4
#
#        diagnosis        diagnosis_category    ALAT    AP    ASAT  BASm#n  \
# 16574     M62.80  Musculoskeletal diseases  1399.0  63.0  4701.0    0.10
# 238133     T82.5        Injury & poisoning   263.0   NaN  2005.0     NaN
# 18622     I71.03      Circulatory diseases   591.0  39.0  1827.0     NaN
# 34631     I71.03      Circulatory diseases   823.0   NaN  3226.0    0.01
# 222479     A40.0       Infectious diseases   230.0   NaN   334.0     NaN
# ...          ...                       ...     ...   ...     ...     ...
# 255808     I34.0      Circulatory diseases     NaN   NaN     NaN     NaN
# 102929     S33.4        Injury & poisoning    25.0   NaN    36.0     NaN
# 130823     I26.0      Circulatory diseases  1976.0   NaN  3147.0    0.02
# 99326      F51.3          Mental disorders     NaN   NaN     NaN     NaN
# 235069     I21.4      Circulatory diseases    12.0  70.0    28.0    0.10
#
#          BIg    CA        CK  CO-HB     CR    CRP  EOSm#n  EPIGFR  Eryn   GGT  \
# 16574    6.0   NaN  589210.0    1.2   43.0  141.0    0.09   145.0  5.81  48.0
# 238133  13.0   NaN  327320.0    1.3   82.0    NaN     NaN     NaN   NaN   NaN
# 18622    7.0   NaN  232020.0    0.1  114.0    1.0     NaN    45.0  3.87   9.0
# 34631    NaN   NaN  214062.0    0.7  198.0    NaN    0.03    33.0  2.94   NaN
# 222479   3.0  1.52  154812.0    0.6  187.0  213.0     NaN    28.0  3.44  11.0
# ...      ...   ...       ...    ...    ...    ...     ...     ...   ...   ...
# 255808   NaN   NaN     550.0    1.6   74.0    1.0     NaN    94.0  5.04   NaN
# 102929   6.0   NaN     550.0    0.8  110.0    2.0     NaN    69.0  4.88  24.0
# 130823  12.0  2.27     550.0    0.3  116.0   90.0    0.00    40.0  4.32  53.0
# 99326    NaN  2.20     550.0    NaN   82.0    4.0     NaN    82.0  4.03   NaN
# 235069   9.0  2.50     550.0    NaN   92.0    1.0    0.10    47.0  4.29  19.0
#
#            GL     H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  \
# 16574    8.80  20.0  12.0  167.0  0.50  1.0   1.0   0.32   1.27  3.7   2.0
# 238133   6.60   9.0   NaN    NaN   NaN  8.0   NaN    NaN    NaN  5.7   9.0
# 18622    8.20  12.0   NaN  112.0  0.32  0.0   NaN    NaN   1.25  4.0  10.0
# 34631    9.10  31.0   NaN   91.0  0.27  3.0   NaN   0.12   1.66  5.1  12.0
# 222479   3.50  16.0   NaN   99.0  0.32  1.0   NaN    NaN   2.11  4.3   1.0
# ...       ...   ...   ...    ...   ...  ...   ...    ...    ...  ...   ...
# 255808   6.03  29.0   NaN  153.0  0.43  1.0   NaN    NaN   0.99  3.7  14.0
# 102929   7.10  11.0   NaN  148.0  0.45  1.0   NaN    NaN   1.02  4.2   9.0
# 130823  11.50   7.0   NaN  134.0  0.37  1.0   NaN   0.15   1.49  4.8   9.0
# 99326    4.70  15.0   NaN  137.0  0.39  3.0   NaN    NaN   1.27  3.5   3.0
# 235069   6.60   7.0   NaN  128.0  0.38  1.0   NaN   0.01   1.08  4.3  17.0
#
#         L-Se  LACT  LYMm#n  Leukn  MCHCn  MCHn  MCVn  MONm#n  MPVn  MTHB  \
# 16574    3.0   3.3    2.31  22.70  351.0  28.0  81.0    0.61  11.1   0.5
# 238133   NaN   NaN     NaN    NaN    NaN   NaN   NaN     NaN   NaN   NaN
# 18622    NaN   5.1     NaN  11.20  344.0  32.0  97.0     NaN   9.6   0.9
# 34631    NaN   5.3    0.98  10.00  360.0  31.0  86.0    0.13   9.9   1.1
# 222479   NaN   7.2     NaN   2.73  350.0  29.0  81.0     NaN  10.5   1.1
# ...      ...   ...     ...    ...    ...   ...   ...     ...   ...   ...
# 255808   NaN   1.8     NaN   7.52  354.0  30.0  86.0     NaN  10.9   1.2
# 102929   NaN   1.2     NaN  17.00  331.0  30.0  92.0     NaN  10.3   1.1
# 130823   NaN   5.2    2.52  18.40  345.0  31.0  87.0    0.71   8.9   0.5
# 99326    NaN   NaN     NaN   7.93  351.0  34.0  97.0     NaN   9.7   NaN
# 235069   NaN   NaN    0.99   6.28  329.0  30.0  89.0    0.63   9.6   NaN
#
#         NEUm#n  NRBCmn     Na   QUHD  Quicks  RDWn   THZn   TNT_hn   TNThsn  \
# 16574    27.62     0.0  128.0   59.7    13.8  14.2  304.0     5.59     5.59
# 238133     NaN     NaN  140.0    NaN     NaN   NaN    NaN      NaN      NaN
# 18622      NaN     0.0  139.0   42.7    12.0  15.3  130.0  2852.00  3769.00
# 34631     3.96     0.2  135.0   39.5    16.3  13.3   66.0      NaN      NaN
# 222479     NaN     0.0  127.0   24.1    20.8  14.0   10.0   243.00   243.00
# ...        ...     ...    ...    ...     ...   ...    ...      ...      ...
# 255808     NaN     0.0  142.0  102.5    10.8  12.8  279.0      NaN      NaN
# 102929     NaN     0.0  141.0   98.4    10.9  13.3  213.0     4.10     4.10
# 130823   13.79     0.1  142.0   46.6    15.6  13.8   34.0   691.00   691.00
# 99326      NaN     0.0  140.0   59.1    13.3  13.2  207.0    13.20    13.20
# 235069    5.63     NaN  138.0   88.7   104.0  13.1  261.0  2069.00  2069.00
#
#         Tbga  UREA  pCO2     pH    pO2    tHb
# 16574   36.1   2.4  29.0  7.512   86.0  169.0
# 238133  36.0   5.0  41.0    NaN  240.0   74.0
# 18622   37.1   9.3  23.0  7.180   32.0   90.0
# 34631   36.0  12.1  41.0  7.198   36.0   91.0
# 222479  35.0   8.8  38.0  6.940   47.0   97.0
# ...      ...   ...   ...    ...    ...    ...
# 255808  35.9   NaN  42.0  7.360   63.0  131.0
# 102929  37.0   6.0  49.0  7.359   60.0  137.0
# 130823  37.0  16.7  24.0  7.362   34.0  134.0
# 99326    NaN   7.9   NaN    NaN    NaN    NaN
# 235069   NaN   9.8   NaN    NaN    NaN    NaN
#
# [7681 rows x 58 columns]
# Extreme upper outliers detected in CO-HB:
#         patient_id  case_id  discharge_type sex  age  length_of_stay_days  \
# 54532        52185   295484  Entl. in ex.KH   m   48                    0
# 54976        52634   170016  Entl. in ex.KH   m   47                    0
# 84095        80581   244479  Entl. in ex.KH   m   69                    0
# 76636        73277   180336  Entl. in ex.KH   m   41                    0
# 1870          1708   120421      Entlassung   m   58                    1
# ...            ...      ...             ...  ..  ...                  ...
# 161860      155514   330220      Entlassung   f   71                    1
# 101028       96771   383570      Entlassung   m   66                   16
# 100982       96721   204058      Entlassung   f   66                    6
# 224832      215838   103802      Entlassung   m   72                    8
# 81711        78240   339118  Entl. in ex.KH   m   66                    5
#
#        diagnosis    diagnosis_category   ALAT     AP   ASAT  BASm#n   BIg  \
# 54532        T58    Injury & poisoning   41.0   56.0   33.0    0.02   3.0
# 54976        T58    Injury & poisoning   22.0    NaN   25.0     NaN   6.0
# 84095      I46.0  Circulatory diseases  150.0    NaN  175.0     NaN   5.0
# 76636        T58    Injury & poisoning    NaN    NaN    NaN     NaN   NaN
# 1870       C78.0             Neoplasms    NaN    NaN    NaN     NaN   NaN
# ...          ...                   ...    ...    ...    ...     ...   ...
# 161860     S40.0    Injury & poisoning   25.0   65.0   37.0    0.05   3.0
# 101028     C04.8             Neoplasms   13.0   77.0   17.0     NaN   NaN
# 100982     K43.2    Digestive diseases    NaN    NaN    NaN     NaN   NaN
# 224832    J44.09  Respiratory diseases   13.0   78.0   22.0    0.08   7.0
# 81711      I26.9  Circulatory diseases   13.0  127.0   30.0    0.03  12.0
#
#           CA     CK  CO-HB     CR   CRP  EOSm#n  EPIGFR  Eryn   GGT     GL  \
# 54532   2.50  442.0   30.9   86.0   0.0    0.08    92.0  4.89  29.0   6.05
# 54976    NaN  235.0   29.7   83.0   1.0     NaN    96.0  4.73  19.0  10.10
# 84095    NaN  155.0   29.6  148.0   2.0     NaN    28.0  4.50  90.0  20.30
# 76636    NaN    NaN   29.5   82.0   1.0     NaN   102.0  5.53   NaN   6.10
# 1870     NaN    NaN   22.6    NaN   NaN     NaN     NaN  3.87   NaN    NaN
# ...      ...    ...    ...    ...   ...     ...     ...   ...   ...    ...
# 161860  2.27  210.0    4.1   64.0   1.0    0.07    84.0  4.43  30.0   5.62
# 101028  2.43    NaN    4.1   57.0  26.0     NaN   102.0  3.82  25.0   6.61
# 100982   NaN    NaN    4.1    NaN   NaN     NaN     NaN   NaN   NaN   9.20
# 224832  1.94    NaN    4.1  164.0  94.0    0.13    36.0  5.27  23.0   5.57
# 81711   2.13   72.0    4.1   64.0  26.0    0.02    97.0  4.31  88.0   5.40
#
#             H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 54532    12.0   NaN  146.0  0.42  0.0   NaN   0.00   1.01  3.3  36.0   NaN
# 54976    18.0   NaN  144.0  0.41  1.0   NaN    NaN   1.04  3.8   7.0   NaN
# 84095   235.0   NaN  147.0  0.46  0.0   NaN    NaN   1.57  4.3  48.0   NaN
# 76636    22.0   NaN  164.0  0.47  1.0   NaN    NaN   1.07  3.8  13.0   NaN
# 1870      NaN   NaN  129.0  0.39  NaN   NaN    NaN   1.14  NaN   NaN   NaN
# ...       ...   ...    ...   ...  ...   ...    ...    ...  ...   ...   ...
# 161860    3.0   NaN  135.0  0.41  1.0   NaN    NaN   1.01  5.1   6.0   NaN
# 101028    8.0   9.0  126.0  0.36  0.0   0.0    NaN   1.02  5.7  20.0  16.0
# 100982    NaN   NaN    NaN   NaN  NaN   NaN    NaN    NaN  5.2   NaN   NaN
# 224832    9.0   NaN  143.0  0.43  1.0   NaN   0.05   1.11  2.3  15.0   NaN
# 81711     6.0   NaN  120.0  0.37  1.0   NaN   0.05   1.18  3.9   6.0   NaN
#
#         LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 54532    NaN    2.18   7.45  347.0  30.0   86.0    0.63  11.1   0.9    4.54
# 54976    3.3     NaN  11.70  351.0  30.0   87.0     NaN   9.8   1.2     NaN
# 84095   11.7     NaN  19.90  321.0  33.0  102.0     NaN  10.3   3.9     NaN
# 76636    1.6     NaN   7.15  347.0  30.0   86.0     NaN  11.5   1.2     NaN
# 1870     NaN     NaN   5.43  332.0  32.0   93.0     NaN   9.0   8.5     NaN
# ...      ...     ...    ...    ...   ...    ...     ...   ...   ...     ...
# 161860   NaN    1.54   6.21  328.0  30.0   93.0    0.45   8.7   0.4    4.09
# ...
# 31441   21.0     NaN    NaN    NaN   NaN    NaN     NaN   NaN   0.9     NaN
# 85378   23.0     NaN   6.28  311.0  30.0   86.0     NaN   9.6   0.8     NaN
# 20688    NaN     NaN    NaN    NaN   NaN    NaN     NaN   NaN   2.6     NaN
# ...      ...     ...    ...    ...   ...    ...     ...   ...   ...     ...
# 127469  13.6     NaN  13.70  339.0  28.0   81.0     NaN  10.5   1.3     NaN
# 29735    1.7     NaN    NaN    NaN   NaN    NaN     NaN   NaN   1.6     NaN
# 156696   NaN     NaN  11.80  358.0  30.0   83.0     NaN  10.3   1.7     NaN
# 14718    5.6     NaN  10.50  327.0  29.0   88.0     NaN   9.8   0.6     NaN
# 183655  10.3    1.99  11.70  353.0  29.0   88.0    0.92   9.4   1.3    8.31
#
#         NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  \
# 94530      0.2  140.0    NaN     NaN  13.0   89.0  2688.0  2688.0  37.0   5.7
# 61302      NaN  140.0    NaN     NaN   NaN    NaN     NaN     NaN  37.0   NaN
# 31441      NaN  142.0    NaN     NaN   NaN    NaN     NaN     NaN  35.5   NaN
# 85378      4.3  147.0   36.6    17.8  12.8  256.0   141.0   141.0  36.0   4.7
# 20688      NaN  140.0    NaN     NaN   NaN    NaN     NaN     NaN  37.0   NaN
# ...        ...    ...    ...     ...   ...    ...     ...     ...   ...   ...
# 127469     0.1  127.0    NaN     NaN  20.7  224.0     NaN     NaN  34.2  10.9
# 29735      NaN  139.0    NaN     NaN   NaN    NaN     NaN     NaN  35.8   NaN
# 156696     0.0  138.0  135.2     9.8  12.4  277.0     NaN     NaN  37.0   NaN
# 14718      0.0  144.0   50.5    13.3  14.2  152.0   393.0   393.0  35.8   7.8
# 183655     0.1  137.0   47.2    13.2  13.3  103.0   118.0   175.0  36.1   6.1
#
#          pCO2     pH    pO2    tHb
# 94530    60.0  6.380  115.0  144.0
# 61302   174.0  6.414   29.0  150.0
# 31441   103.0  6.429   27.0   77.0
# 85378    26.0  6.439   50.0  100.0
# 20688   102.0  6.490   53.0  144.0
# ...       ...    ...    ...    ...
# 127469   29.0  7.090  134.0   96.0
# 29735    75.0  7.091  100.0  122.0
# 156696   77.0  7.091   11.0  167.0
# 14718    30.0  7.091   88.0  117.0
# 183655   42.0  7.091   89.0   99.0
#
# [609 rows x 58 columns]
# Extreme upper outliers detected in pH:
#         patient_id  case_id   discharge_type sex  age  length_of_stay_days  \
# 151478      145594   322800       Entlassung   m   84                    4
# 37700        36149   131751       Entlassung   m   83                    8
# 77008        73631   305801       Entlassung   m   73                    4
# 251713      233227   412535       Entlassung   m   65                    6
# 126614      121344   295263       Entlassung   f   56                    8
# 35998        34515    82016       Entlassung   m   73                   16
# 185781      179009   279031  Entl.ext.Instit   f   65                    2
# 210290      202370   293967       Entlassung   m   44                    3
# 83737        80211   139965       Verstorben   f   85                   10
# 143726      137957   171974  Entl.ext.Instit   f   71                    3
#
#        diagnosis      diagnosis_category   ALAT     AP  ASAT  BASm#n   BIg  \
# 151478     I21.4    Circulatory diseases    NaN    NaN   NaN     NaN   NaN
# 37700      N99.0  Genitourinary diseases   32.0  120.0  43.0     NaN  55.0
# 77008      I48.0    Circulatory diseases    NaN    NaN   NaN     NaN   NaN
# 251713     K42.0      Digestive diseases   27.0   93.0  45.0    0.02  43.0
# 126614    S82.31      Injury & poisoning   17.0   50.0  21.0    0.08   9.0
# 35998      J15.1    Respiratory diseases    NaN    NaN   NaN     NaN   NaN
# 185781     F33.3        Mental disorders    NaN    NaN   NaN     NaN   NaN
# 210290     N99.0  Genitourinary diseases   28.0    NaN  32.0    0.04  10.0
# 83737     C79.83               Neoplasms  122.0  243.0  80.0     NaN  26.0
# 143726     K43.3      Digestive diseases   29.0   90.0  62.0    0.03  17.0
#
#           CA     CK  CO-HB     CR   CRP  EOSm#n  EPIGFR  Eryn    GGT    GL  \
# 151478   NaN  606.0    0.5  110.0   NaN     NaN    53.0  4.73    NaN  7.60
# 37700   2.41  225.0    1.6  137.0  14.0     NaN    41.0  4.51  122.0  9.10
# 77008    NaN   85.0    1.3   74.0   0.0     NaN    87.0  4.35    NaN  6.40
# 251713  2.68    NaN    1.6  250.0   6.0    0.01    22.0  3.92  103.0  7.00
# 126614  2.49    NaN    1.1   66.0   1.0    0.05    90.0  4.74   28.0  7.85
# 35998    NaN    NaN    2.4   17.0  87.0     NaN   159.0  4.23    NaN   NaN
# 185781   NaN    NaN    1.1   66.0   1.0     NaN    84.0  4.40    NaN  5.60
# 210290   NaN  182.0    1.5  304.0   8.0    0.20    20.0  4.59   23.0  5.70
# 83737    NaN  175.0    0.7    NaN  11.0     NaN     NaN  4.34  192.0  8.60
# 143726  2.49    NaN    0.6   62.0  16.0    0.01    87.0  2.90  420.0  9.50
#
#            H   H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 151478  13.0    NaN  154.0  0.43  2.0   NaN    NaN   0.98  4.2   7.0   NaN
# 37700   15.0    NaN  149.0  0.44  5.0   NaN    NaN   1.38  2.7   7.0   NaN
# 77008    7.0  122.0  143.0  0.45  1.0   1.0    NaN   1.02  3.7   8.0  11.0
# 251713   8.0    NaN  147.0  0.37  3.0   NaN   0.02   1.26  3.4  11.0   NaN
# 126614  10.0    NaN  139.0  0.39  2.0   NaN   0.09   0.94  2.8   2.0   NaN
# 35998    9.0    NaN  124.0  0.39  0.0   NaN    NaN    NaN  3.3   8.0   NaN
# 185781  19.0    NaN  138.0  0.38  1.0   NaN    NaN   0.94  3.6  14.0   NaN
# 210290  41.0   54.0  154.0  0.43  1.0   1.0   0.09   1.29  6.5  12.0   9.0
# 83737   37.0    NaN  125.0  0.37  2.0   NaN    NaN   1.24  4.4   2.0   NaN
# 143726   3.0    NaN  103.0  0.28  1.0   NaN   0.03   1.37  2.9   9.0   NaN
#
#         LACT  LYMm#n  Leukn  MCHCn  MCHn  MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 151478   1.9     NaN   9.67  362.0  33.0  90.0     NaN   9.1   0.6     NaN
# 37700    2.1     NaN  14.00  364.0  36.0  95.0     NaN   9.8   0.3     NaN
# 77008    2.0     NaN  13.10  354.0  33.0  91.0     NaN  12.1   0.4     NaN
# 251713   4.7    1.22   5.10  348.0  32.0  91.0    0.89  10.5   0.4    4.67
# 126614   3.2    3.32  14.50  359.0  29.0  82.0    0.94   8.9   0.6   10.06
# 35998    NaN     NaN   7.42  320.0  29.0  92.0     NaN  10.2   0.4     NaN
# 185781   2.0     NaN   7.21  359.0  31.0  87.0     NaN   9.2   0.7     NaN
# 210290   1.3    2.73  12.30  341.0  31.0  88.0    1.10  12.8   0.7    8.15
# 83737    2.8     NaN   7.19  338.0  29.0  85.0     NaN  11.4   0.4     NaN
# 143726   2.4    0.99   6.38  366.0  36.0  98.0    0.72  10.3   0.4    4.60
#
#         NRBCmn     Na   QUHD  Quicks  RDWn   THZn   TNT_hn   TNThsn  Tbga  \
# 151478     0.0  136.0  104.9    11.0  12.0  216.0  3151.00  3151.00  36.7
# 37700      0.0  130.0   48.7    15.0  12.8  146.0    51.20    48.30  37.0
# 77008      0.0  136.0   96.3    10.9  12.7  252.0     6.32     6.32  36.0
# 251713     0.0  136.0   59.6    13.5  15.0   69.0      NaN      NaN  36.7
# 126614     0.0  138.0  117.2    10.1  12.8  354.0      NaN      NaN  37.0
# 35998      0.0  142.0    NaN     NaN  17.8  190.0      NaN      NaN  37.0
# 185781     0.0  143.0  119.2    10.3  12.9  219.0      NaN      NaN  37.0
# 210290     0.0  134.0   57.5    13.5  12.2  125.0   152.00   152.00  37.0
# 83737      0.0  135.0   60.9    13.5  14.8  200.0    25.80    25.80  35.8
# 143726     0.2  128.0   51.0    14.4  12.4   96.0      NaN      NaN  37.0
#
#         UREA  pCO2     pH    pO2    tHb
# 151478   NaN  11.0  7.761  121.0  118.0
# 37700   24.5  18.0  7.731  127.0  156.0
# 77008    4.1   9.0  7.727  102.0  160.0
# 251713   NaN  31.0  7.709   58.0  142.0
# 126614   NaN  14.0  7.706   50.0  145.0
# 35998    NaN  20.0  7.704   47.0  119.0
# 185781   NaN   9.0  7.693  124.0  147.0
# 210290  12.0  39.0  7.693   18.0  146.0
# 83737   12.3  13.0  7.685   53.0  119.0
# 143726   NaN  38.0  7.681   58.0  123.0
# Extreme upper outliers detected in pO2:
#         patient_id  case_id  discharge_type sex  age  length_of_stay_days  \
# 255547      234899   410645      Entlassung   m   41                    8
# 15223        14389   241293      Verstorben   m   36                    0
# 151828      145926    64701      Verstorben   f   71                    3
# 121729      116737   361210      Verstorben   m   51                    0
# 201611      194151   366332  Entl. in ex.KH   m   79                    1
# ...            ...      ...             ...  ..  ...                  ...
# 54618        52289   176584      Entlassung   m   40                    2
# 126342      121086   124382      Entlassung   f   65                    4
# 111063      106424   264600      Entlassung   f   56                   12
# 132374      126930   262678      Entlassung   m   33                    9
# 205464      197719   383631      Verstorben   m   63                    1
#
#        diagnosis        diagnosis_category   ALAT     AP   ASAT  BASm#n   BIg  \
# 255547     I21.1      Circulatory diseases   64.0    NaN   44.0     NaN   9.0
# 15223      I46.9      Circulatory diseases    NaN    NaN    NaN     NaN   NaN
# 151828     I60.3      Circulatory diseases    NaN    NaN   31.0     NaN   NaN
# 121729    I50.01      Circulatory diseases   52.0    NaN  147.0    0.03  21.0
# 201611     J45.9      Respiratory diseases    NaN    NaN    NaN    0.00   NaN
# ...          ...                       ...    ...    ...    ...     ...   ...
# 54618      G43.0   Nervous system diseases   19.0    NaN   21.0     NaN   7.0
# 126342     M16.9  Musculoskeletal diseases    NaN    NaN    NaN     NaN   NaN
# 111063     C24.0                 Neoplasms  180.0  287.0  126.0     NaN  12.0
# 132374    I67.10      Circulatory diseases    NaN    NaN    NaN     NaN   NaN
# 205464     I21.0      Circulatory diseases   90.0    NaN  120.0    0.08   5.0
#
#           CA     CK  CO-HB     CR   CRP  EOSm#n  EPIGFR  Eryn    GGT    GL  \
# 255547  2.29  146.0    1.0   57.0  38.0     NaN    91.0  6.71  124.0  11.2
# 15223    NaN    NaN    0.0    NaN   NaN     NaN     NaN  1.63    NaN   1.3
# 151828  2.28  131.0    1.0   80.0   0.0     NaN    64.0  4.58   18.0   8.6
# 121729  2.09  978.0    0.8  173.0   5.0    0.02    39.0  3.88   62.0   4.3
# 201611   NaN  388.0    3.1   70.0  18.0    0.00    85.0  4.50    NaN   7.5
# ...      ...    ...    ...    ...   ...     ...     ...   ...    ...   ...
# 54618    NaN  101.0    0.3   60.0   1.0     NaN   120.0  5.54   21.0   5.7
# 126342   NaN    NaN    1.5   73.0   1.0     NaN    60.0  3.19    NaN   7.0
# 111063   NaN    NaN    1.3   51.0   NaN     NaN   104.0  2.81    NaN   7.8
# 132374   NaN    NaN    2.0   77.0   2.0     NaN   113.0  5.35    NaN   7.1
# 205464   NaN  153.0    1.1  100.0   6.0    0.39    69.0  5.19   49.0  37.0
#
#            H  H-Se    Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA     L  L-Se  \
# 255547   9.0   NaN  146.0  0.43  1.0   NaN    NaN   1.14  3.1   8.0   NaN
# 15223    NaN   NaN   48.0  0.17  NaN   NaN    NaN    NaN  6.3   NaN   NaN
# 151828  17.0  23.0  143.0  0.42  1.0   1.0    NaN   1.08  4.6   9.0  11.0
# 121729  68.0   NaN  108.0  0.33  2.0   NaN   0.28    NaN  6.2   3.0   NaN
# 201611   4.0   NaN  132.0  0.40  7.0   NaN   0.04   0.87  4.1   3.0   NaN
# ...      ...   ...    ...   ...  ...   ...    ...    ...  ...   ...   ...
# 54618   10.0   NaN  163.0  0.47  1.0   NaN    NaN   1.08  4.1   8.0   NaN
# 126342   9.0   NaN   74.0  0.22  1.0   NaN    NaN   1.29  3.8  19.0   NaN
# 111063   1.0   NaN   85.0  0.25  1.0   NaN    NaN   1.11  4.3   8.0   NaN
# 132374   8.0   NaN  157.0  0.46  2.0   NaN    NaN   1.02  4.2   4.0   NaN
# 205464  63.0   NaN  150.0  0.49  1.0   NaN   0.37    NaN  6.5   7.0   NaN
#
#         LACT  LYMm#n  Leukn  MCHCn  MCHn   MCVn  MONm#n  MPVn  MTHB  NEUm#n  \
# 255547   9.0     NaN  17.10  338.0  25.0   74.0     NaN  11.2   0.7     NaN
# 15223   28.0     NaN   2.58  289.0  29.0  102.0     NaN   9.8   0.0     NaN
# 151828   0.9     NaN  12.20  345.0  31.0   91.0     NaN   9.8   1.7     NaN
# 121729   9.2    1.56  10.90  331.0  28.0   84.0    0.24  11.5   0.9    8.80
# 201611   5.3    0.52  11.30  326.0  29.0   90.0    0.04   9.1   1.3    8.37
# ...      ...     ...    ...    ...   ...    ...     ...   ...   ...     ...
# 54618    1.0     NaN   8.55  348.0  29.0   84.0     NaN   9.9   1.0     NaN
# 126342   0.9     NaN   3.60  329.0  32.0   97.0     NaN   9.9   0.8     NaN
# 111063   1.1     NaN  13.20  344.0  30.0   88.0     NaN  10.7   0.7     NaN
# 132374   1.6     NaN   5.99  342.0  29.0   86.0     NaN  12.1   1.0     NaN
# 205464  16.0    7.98  14.30  306.0  29.0   94.0    0.86  12.4   1.5    4.62
#
#         NRBCmn     Na   QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  \
# 255547     0.0  140.0  101.4    10.7  13.8  216.0   61.30   61.30  37.0   5.4
# 15223      0.4  133.0    NaN     NaN  14.2   21.0     NaN     NaN  37.0   NaN
# 151828     0.0  135.0   86.1    11.4  12.8  323.0    7.19    7.19  37.0   8.7
# 121729     0.1  131.0    NaN     NaN  13.9   75.0     NaN     NaN  30.9  10.8
# 201611     0.0  138.0  121.1     NaN  14.4  242.0   12.50   22.29  35.0   3.6
# ...        ...    ...    ...     ...   ...    ...     ...     ...   ...   ...
# 54618      0.0  141.0   86.1    11.4  12.7  213.0    3.00    3.00  36.3   4.2
# 126342     0.2  143.0   71.4    12.5  19.0   83.0     NaN     NaN  36.2   NaN
# 111063     0.1  136.0   79.6    12.0  11.9  217.0     NaN     NaN  35.7   5.8
# 132374     0.0  136.0   98.4    10.9  12.4  214.0     NaN     NaN  36.4   NaN
# 205464     0.5  137.0    NaN     NaN  14.2   85.0  392.00  392.00  36.0   8.5
#
#         pCO2     pH    pO2    tHb
# 255547  27.0  7.410  562.0  152.0
# 15223   38.0  6.554  560.0   25.0
# 151828  34.0  7.371  547.0  125.0
# 121729  21.0  7.504  543.0  109.0
# 201611  66.0  7.353  543.0  128.0
# ...      ...    ...    ...    ...
# 54618   35.0  7.401  275.0  164.0
# 126342  40.0  7.356  275.0   95.0
# 111063  38.0  7.391  275.0   80.0
# 132374  42.0  7.360  275.0  146.0
# 205464  56.0  6.780  275.0  153.0
#
# [1492 rows x 58 columns]
# Extreme lower outliers detected in tHb:
#        patient_id  case_id discharge_type sex  age  length_of_stay_days  \
# 20905       19954    90769     Entlassung   f   65                    4
#
#       diagnosis  diagnosis_category  ALAT    AP  ASAT  BASm#n  BIg    CA  \
# 20905     K91.3  Digestive diseases  16.0  83.0  34.0    0.02  5.0  2.37
#
#           CK  CO-HB    CR  CRP  EOSm#n  EPIGFR  Eryn   GGT   GL     H  H-Se  \
# 20905  197.0    NaN  84.0  1.0    0.02    63.0  2.77  23.0  5.9  35.0   NaN
#
#         Hbn   Hkn    I  I-Se  IGm#n  INRiH   KA    L  L-Se  LACT  LYMm#n  \
# 20905  83.0  0.25  1.0   NaN   0.04   1.04  4.0  7.0   NaN   1.1    0.69
#
#        Leukn  MCHCn  MCHn  MCVn  MONm#n  MPVn  MTHB  NEUm#n  NRBCmn     Na  \
# 20905   6.07  334.0  30.0  88.0    0.24  11.0   NaN    7.28     0.0  142.0
#
#        QUHD  Quicks  RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  pCO2  pH  pO2  \
# 20905  91.3    11.2  17.2  144.0    10.3    10.3   NaN   NaN   NaN NaN  NaN
#
#        tHb
# 20905  0.0
# Extreme upper outliers detected in tHb:
#        patient_id  case_id discharge_type sex  age  length_of_stay_days  \
# 46880       44993   115187     Entlassung   f   77                    8
#
#       diagnosis  diagnosis_category  ALAT     AP  ASAT  BASm#n  BIg    CA  CK  \
# 46880    K57.31  Digestive diseases  22.0  367.0  32.0    0.02  7.0  2.17 NaN
#
#        CO-HB    CR    CRP  EOSm#n  EPIGFR  Eryn   GGT    GL   H  H-Se    Hbn  \
# 46880    1.0  85.0  212.0    0.08    57.0  3.13  88.0  5.31 NaN   NaN  102.0
#
#        Hkn   I  I-Se  IGm#n  INRiH  KA   L  L-Se  LACT  LYMm#n  Leukn  MCHCn  \
# 46880  0.3 NaN   NaN    NaN   1.03 NaN NaN   NaN   NaN    1.35   12.8  346.0
#
#        MCHn  MCVn  MONm#n  MPVn  MTHB  NEUm#n  NRBCmn     Na  QUHD  Quicks  \
# 46880  33.0  94.0    1.37   8.5   0.0   10.02     NaN  130.0  92.3    11.0
#
#        RDWn   THZn  TNT_hn  TNThsn  Tbga  UREA  pCO2  pH  pO2    tHb
# 46880  13.8  332.0     NaN     NaN   NaN   5.5   NaN NaN  NaN  244.0

# %% [markdown]
# ## 3. Handle placeholders, errors and implausible entries

# %%
# Remove Eryn = 0
merged_data['Eryn'] = merged_data['Eryn'].replace(0, np.nan)

# Remove GL = 0
merged_data['GL'] = merged_data['GL'].replace(0, np.nan)

# Remove Hbn = 0
merged_data['Hbn'] = merged_data['Hbn'].replace(0, np.nan)

# Replace Hkn = 42.00 and Hkn = 36.50 with 4.20 and 3.65 respectively
merged_data['Hkn'] = merged_data['Hkn'].replace({42.00: 4.20, 36.50: 3.65})

# Remove Hkn = 0
merged_data['Hkn'] = merged_data['Hkn'].replace(0, np.nan)

# Remove INRiH = 9999.0
merged_data['INRiH'] = merged_data['INRiH'].replace(9999.0, np.nan)

# Remove INRiH = 0.0 (or replace with 0.6, lowest INRiH in the dataset)
merged_data['INRiH'] = merged_data['INRiH'].replace(0.0, np.nan)
#merged_data['INRiH'] = merged_data['INRiH'].replace(0.0, 0.6)

# Remove QUHD = 9999.0 (or replace with 173.2, which is the max value in the dataset < 9999.0)
merged_data['QUHD'] = merged_data['QUHD'].replace(9999.0, np.nan)
#merged_data['QUHD'] = merged_data['QUHD'].replace(9999.0, 173.2)

# Remove tHb = 0
merged_data['tHb'] = merged_data['tHb'].replace(0, np.nan)

# %% [markdown]
# ## 4. Save merged dataset

# %%
merged_data.to_csv(otl_merged_data_path, index=False)
